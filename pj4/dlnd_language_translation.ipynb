# %% [markdown]
# # Language Translation
# In this project, you’re going to take a peek into the realm of neural network machine translation.  You’ll be training a sequence to sequence model on a dataset of English and French sentences that can translate new sentences from English to French.
# ## Get the Data
# Since translating the whole language of English to French will take lots of time to train, we have provided you with a small portion of the English corpus.

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
import helper
import problem_unittests as tests

source_path = 'data/small_vocab_en'
target_path = 'data/small_vocab_fr'
source_text = helper.load_data(source_path)
target_text = helper.load_data(target_path)

# %% [markdown]
# ## Explore the Data
# Play around with view_sentence_range to view different parts of the data.

# %%
view_sentence_range = (0, 10)

"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
import numpy as np

print('Dataset Stats')
print('Roughly the number of unique words: {}'.format(len({word: None for word in source_text.split()})))

sentences = source_text.split('\n')
word_counts = [len(sentence.split()) for sentence in sentences]
print('Number of sentences: {}'.format(len(sentences)))
print('Average number of words in a sentence: {}'.format(np.average(word_counts)))

print()
print('English sentences {} to {}:'.format(*view_sentence_range))
print('\n'.join(source_text.split('\n')[view_sentence_range[0]:view_sentence_range[1]]))
print()
print('French sentences {} to {}:'.format(*view_sentence_range))
print('\n'.join(target_text.split('\n')[view_sentence_range[0]:view_sentence_range[1]]))
# Out:
# Dataset Stats
# Roughly the number of unique words: 227
# Number of sentences: 137861
# Average number of words in a sentence: 13.225277634719028
#
# English sentences 0 to 10:
# new jersey is sometimes quiet during autumn , and it is snowy in april .
# the united states is usually chilly during july , and it is usually freezing in november .
# california is usually quiet during march , and it is usually hot in june .
# the united states is sometimes mild during june , and it is cold in september .
# your least liked fruit is the grape , but my least liked is the apple .
# his favorite fruit is the orange , but my favorite is the grape .
# paris is relaxing during december , but it is usually chilly in july .
# new jersey is busy during spring , and it is never hot in march .
# our least liked fruit is the lemon , but my least liked is the grape .
# the united states is sometimes busy during january , and it is sometimes warm in november .
#
# French sentences 0 to 10:
# new jersey est parfois calme pendant l' automne , et il est neigeux en avril .
# les états-unis est généralement froid en juillet , et il gèle habituellement en novembre .
# california est généralement calme en mars , et il est généralement chaud en juin .
# les états-unis est parfois légère en juin , et il fait froid en septembre .
# votre moins aimé fruit est le raisin , mais mon moins aimé est la pomme .
# son fruit préféré est l'orange , mais mon préféré est le raisin .
# paris est relaxant en décembre , mais il est généralement froid en juillet .
# new jersey est occupé au printemps , et il est jamais chaude en mars .
# notre fruit est moins aimé le citron , mais mon moins aimé est le raisin .
# les états-unis est parfois occupé en janvier , et il est parfois chaud en novembre .

# %% [markdown]
# ## Implement Preprocessing Function
# ### Text to Word Ids
# As you did with other RNNs, you must turn the text into a number so the computer can understand it. In the function `text_to_ids()`, you'll turn `source_text` and `target_text` from words to ids.  However, you need to add the `<EOS>` word id at the end of `target_text`.  This will help the neural network predict when the sentence should end.
#
# You can get the `<EOS>` word id by doing:
# ```python
# target_vocab_to_int['<EOS>']
# ```
# You can get other word ids using `source_vocab_to_int` and `target_vocab_to_int`.

# %%
def text_to_ids(source_text, target_text, source_vocab_to_int, target_vocab_to_int):
    """
    Convert source and target text to proper word ids
    :param source_text: String that contains all the source text.
    :param target_text: String that contains all the target text.
    :param source_vocab_to_int: Dictionary to go from the source words to an id
    :param target_vocab_to_int: Dictionary to go from the target words to an id
    :return: A tuple of lists (source_id_text, target_id_text)
    """
    # TODO: Implement Function
    eos = source_vocab_to_int['<EOS>']
    source_id_text = [[source_vocab_to_int[word] for word in sentence.split()] for sentence in source_text.split('\n')]
    target_id_text = [[target_vocab_to_int[word] for word in sentence.split()] + [eos] for sentence in target_text.split('\n')]
    return source_id_text, target_id_text

"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_text_to_ids(text_to_ids)
# Out:
# Tests Passed

# %% [markdown]
# ### Preprocess all the data and save it
# Running the code cell below will preprocess all the data and save it to file.

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
helper.preprocess_and_save_data(source_path, target_path, text_to_ids)

# %% [markdown]
# # Check Point
# This is your first checkpoint. If you ever decide to come back to this notebook or have to restart the notebook, you can start from here. The preprocessed data has been saved to disk.

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
import numpy as np
import helper
import problem_unittests as tests

(source_int_text, target_int_text), (source_vocab_to_int, target_vocab_to_int), _ = helper.load_preprocess()

# %% [markdown]
# ### Check the Version of TensorFlow and Access to GPU
# This will check to make sure you have the correct version of TensorFlow and access to a GPU

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
from distutils.version import LooseVersion
import warnings
import tensorflow as tf
from tensorflow.python.layers.core import Dense

# Check TensorFlow Version
assert LooseVersion(tf.__version__) >= LooseVersion('1.1'), 'Please use TensorFlow version 1.1 or newer'
print('TensorFlow Version: {}'.format(tf.__version__))

# Check for a GPU
if not tf.test.gpu_device_name():
    warnings.warn('No GPU found. Please use a GPU to train your neural network.')
else:
    print('Default GPU Device: {}'.format(tf.test.gpu_device_name()))
# Out:
# TensorFlow Version: 1.1.0
# Default GPU Device: /gpu:0

# %% [markdown]
# ## Build the Neural Network
# You'll build the components necessary to build a Sequence-to-Sequence model by implementing the following functions below:
# - `model_inputs`
# - `process_decoder_input`
# - `encoding_layer`
# - `decoding_layer_train`
# - `decoding_layer_infer`
# - `decoding_layer`
# - `seq2seq_model`
#
# ### Input
# Implement the `model_inputs()` function to create TF Placeholders for the Neural Network. It should create the following placeholders:
#
# - Input text placeholder named "input" using the TF Placeholder name parameter with rank 2.
# - Targets placeholder with rank 2.
# - Learning rate placeholder with rank 0.
# - Keep probability placeholder named "keep_prob" using the TF Placeholder name parameter with rank 0.
# - Target sequence length placeholder named "target_sequence_length" with rank 1
# - Max target sequence length tensor named "max_target_len" getting its value from applying tf.reduce_max on the target_sequence_length placeholder. Rank 0.
# - Source sequence length placeholder named "source_sequence_length" with rank 1
#
# Return the placeholders in the following the tuple (input, targets, learning rate, keep probability, target sequence length, max target sequence length, source sequence length)

# %%
def model_inputs():
    """
    Create TF Placeholders for input, targets, learning rate, and lengths of source and target sequences.
    :return: Tuple (input, targets, learning rate, keep probability, target sequence length,
    max target sequence length, source sequence length)
    """
    # TODO: Implement Function
    inputs = tf.placeholder(tf.int32, [None, None], name='input')
    targets = tf.placeholder(tf.int32, [None, None], name='targets')
    learning_rate = tf.placeholder(tf.float32, name='learning_rate')
    keep_prob = tf.placeholder(tf.float32, name='keep_prob')
    target_seq_length = tf.placeholder(tf.int32, [None], name='target_sequence_length')
    max_target_seq_length = tf.reduce_max(target_seq_length, name='max_target_len')
    source_seq_length = tf.placeholder(tf.int32, [None], name='source_sequence_length')
    return inputs, targets, learning_rate, keep_prob, target_seq_length, max_target_seq_length, source_seq_length


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_model_inputs(model_inputs)
# Out:
# Tests Passed

# %% [markdown]
# ### Process Decoder Input
# Implement `process_decoder_input` by removing the last word id from each batch in `target_data` and concat the GO ID to the begining of each batch.

# %%
def process_decoder_input(target_data, target_vocab_to_int, batch_size):
    """
    Preprocess target data for encoding
    :param target_data: Target Placehoder
    :param target_vocab_to_int: Dictionary to go from the target words to an id
    :param batch_size: Batch Size
    :return: Preprocessed target data
    """
    # TODO: Implement Function
    go_id = source_vocab_to_int['<GO>']
    ending = tf.strided_slice(target_data, [0, 0], [batch_size, -1], [1, 1])
    proced_target = tf.concat([tf.fill([batch_size, 1], go_id), ending], 1)
    return proced_target

"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_process_encoding_input(process_decoder_input)
# Out:
# Tests Passed

# %% [markdown]
# ### Encoding
# Implement `encoding_layer()` to create a Encoder RNN layer:
#  * Embed the encoder input using [`tf.contrib.layers.embed_sequence`](https://www.tensorflow.org/api_docs/python/tf/contrib/layers/embed_sequence)
#  * Construct a [stacked](https://github.com/tensorflow/tensorflow/blob/6947f65a374ebf29e74bb71e36fd82760056d82c/tensorflow/docs_src/tutorials/recurrent.md#stacking-multiple-lstms) [`tf.contrib.rnn.LSTMCell`](https://www.tensorflow.org/api_docs/python/tf/contrib/rnn/LSTMCell) wrapped in a [`tf.contrib.rnn.DropoutWrapper`](https://www.tensorflow.org/api_docs/python/tf/contrib/rnn/DropoutWrapper)
#  * Pass cell and embedded input to [`tf.nn.dynamic_rnn()`](https://www.tensorflow.org/api_docs/python/tf/nn/dynamic_rnn)

# %%
from imp import reload
reload(tests)

def encoding_layer(rnn_inputs, rnn_size, num_layers, keep_prob, 
                   source_sequence_length, source_vocab_size, 
                   encoding_embedding_size):
    """
    Create encoding layer
    :param rnn_inputs: Inputs for the RNN
    :param rnn_size: RNN Size
    :param num_layers: Number of layers
    :param keep_prob: Dropout keep probability
    :param source_sequence_length: a list of the lengths of each sequence in the batch
    :param source_vocab_size: vocabulary size of source data
    :param encoding_embedding_size: embedding size of source data
    :return: tuple (RNN output, RNN state)
    """
    # TODO: Implement Function
    def lstm_cell(rnn_size, keep_prob):
        lstm = tf.contrib.rnn.LSTMCell(rnn_size)
        lstm = tf.contrib.rnn.DropoutWrapper(lstm, output_keep_prob=keep_prob)
        return lstm
    
    embed_input = tf.contrib.layers.embed_sequence(rnn_inputs, embed_dim=encoding_embedding_size, vocab_size=source_vocab_size)
    
    stacked_cell = tf.contrib.rnn.MultiRNNCell([lstm_cell(rnn_size, keep_prob) for _ in range(num_layers)])
    rnn, state = tf.nn.dynamic_rnn(stacked_cell, embed_input, source_sequence_length, dtype=tf.float32)
    return rnn, state

"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_encoding_layer(encoding_layer)
# Out:
# Tests Passed

# %% [markdown]
# ### Decoding - Training
# Create a training decoding layer:
# * Create a [`tf.contrib.seq2seq.TrainingHelper`](https://www.tensorflow.org/api_docs/python/tf/contrib/seq2seq/TrainingHelper)
# * Create a [`tf.contrib.seq2seq.BasicDecoder`](https://www.tensorflow.org/api_docs/python/tf/contrib/seq2seq/BasicDecoder)
# * Obtain the decoder outputs from [`tf.contrib.seq2seq.dynamic_decode`](https://www.tensorflow.org/api_docs/python/tf/contrib/seq2seq/dynamic_decode)

# %%
def decoding_layer_train(encoder_state, dec_cell, dec_embed_input, 
                         target_sequence_length, max_summary_length, 
                         output_layer, keep_prob):
    """
    Create a decoding layer for training
    :param encoder_state: Encoder State
    :param dec_cell: Decoder RNN Cell
    :param dec_embed_input: Decoder embedded input
    :param target_sequence_length: The lengths of each sequence in the target batch
    :param max_summary_length: The length of the longest sequence in the batch
    :param output_layer: Function to apply the output layer
    :param keep_prob: Dropout keep probability
    :return: BasicDecoderOutput containing training logits and sample_id
    """
    # TODO: Implement Function
    helper = tf.contrib.seq2seq.TrainingHelper(dec_embed_input, target_sequence_length)
    decoder = tf.contrib.seq2seq.BasicDecoder(dec_cell, helper, encoder_state, output_layer)
    f_output, _ = tf.contrib.seq2seq.dynamic_decode(decoder, maximum_iterations=max_summary_length)
    return f_output



"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_decoding_layer_train(decoding_layer_train)
# Out:
# Tests Passed

# %% [markdown]
# ### Decoding - Inference
# Create inference decoder:
# * Create a [`tf.contrib.seq2seq.GreedyEmbeddingHelper`](https://www.tensorflow.org/api_docs/python/tf/contrib/seq2seq/GreedyEmbeddingHelper)
# * Create a [`tf.contrib.seq2seq.BasicDecoder`](https://www.tensorflow.org/api_docs/python/tf/contrib/seq2seq/BasicDecoder)
# * Obtain the decoder outputs from [`tf.contrib.seq2seq.dynamic_decode`](https://www.tensorflow.org/api_docs/python/tf/contrib/seq2seq/dynamic_decode)

# %%
def decoding_layer_infer(encoder_state, dec_cell, dec_embeddings, start_of_sequence_id,
                         end_of_sequence_id, max_target_sequence_length,
                         vocab_size, output_layer, batch_size, keep_prob):
    """
    Create a decoding layer for inference
    :param encoder_state: Encoder state
    :param dec_cell: Decoder RNN Cell
    :param dec_embeddings: Decoder embeddings
    :param start_of_sequence_id: GO ID
    :param end_of_sequence_id: EOS Id
    :param max_target_sequence_length: Maximum length of target sequences
    :param vocab_size: Size of decoder/target vocabulary
    :param decoding_scope: TenorFlow Variable Scope for decoding
    :param output_layer: Function to apply the output layer
    :param batch_size: Batch size
    :param keep_prob: Dropout keep probability
    :return: BasicDecoderOutput containing inference logits and sample_id
    """
    # TODO: Implement Function
    start_ids = tf.tile([start_of_sequence_id], [batch_size])
    helper = tf.contrib.seq2seq.GreedyEmbeddingHelper(dec_embeddings, start_ids, end_of_sequence_id)
    decoder = tf.contrib.seq2seq.BasicDecoder(dec_cell, helper, encoder_state, output_layer)
    f_output, _ = tf.contrib.seq2seq.dynamic_decode(decoder, maximum_iterations=max_target_sequence_length)
    return f_output



"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_decoding_layer_infer(decoding_layer_infer)
# Out:
# Tests Passed

# %% [markdown]
# ### Build the Decoding Layer
# Implement `decoding_layer()` to create a Decoder RNN layer.
#
# * Embed the target sequences
# * Construct the decoder LSTM cell (just like you constructed the encoder cell above)
# * Create an output layer to map the outputs of the decoder to the elements of our vocabulary
# * Use the your `decoding_layer_train(encoder_state, dec_cell, dec_embed_input, target_sequence_length, max_target_sequence_length, output_layer, keep_prob)` function to get the training logits.
# * Use your `decoding_layer_infer(encoder_state, dec_cell, dec_embeddings, start_of_sequence_id, end_of_sequence_id, max_target_sequence_length, vocab_size, output_layer, batch_size, keep_prob)` function to get the inference logits.
#
# Note: You'll need to use [tf.variable_scope](https://www.tensorflow.org/api_docs/python/tf/variable_scope) to share variables between training and inference.

# %%
def decoding_layer(dec_input, encoder_state,
                   target_sequence_length, max_target_sequence_length,
                   rnn_size,
                   num_layers, target_vocab_to_int, target_vocab_size,
                   batch_size, keep_prob, decoding_embedding_size):
    """
    Create decoding layer
    :param dec_input: Decoder input
    :param encoder_state: Encoder state
    :param target_sequence_length: The lengths of each sequence in the target batch
    :param max_target_sequence_length: Maximum length of target sequences
    :param rnn_size: RNN Size
    :param num_layers: Number of layers
    :param target_vocab_to_int: Dictionary to go from the target words to an id
    :param target_vocab_size: Size of target vocabulary
    :param batch_size: The size of the batch
    :param keep_prob: Dropout keep probability
    :param decoding_embedding_size: Decoding embedding size
    :return: Tuple of (Training BasicDecoderOutput, Inference BasicDecoderOutput)
    """
    # TODO: Implement Function
    def lstm_cell(rnn_size, keep_prob):
        lstm = tf.contrib.rnn.LSTMCell(rnn_size)
        lstm = tf.contrib.rnn.DropoutWrapper(lstm, output_keep_prob=keep_prob)
        return lstm
    stacked_cell = tf.contrib.rnn.MultiRNNCell([lstm_cell(rnn_size, keep_prob) for _ in range(num_layers)])
    
    dec_embeddings = tf.Variable(tf.random_uniform([target_vocab_size, decoding_embedding_size]))
    dec_embed_input = tf.nn.embedding_lookup(dec_embeddings, dec_input)
    
    dense_layer = Dense(target_vocab_size, kernel_initializer=tf.truncated_normal_initializer(mean=0.0, stddev=0.1))
    
    with tf.variable_scope('decode') as scope:
        tr_decoder_output = decoding_layer_train(
                                    encoder_state, stacked_cell, dec_embed_input, 
                                    target_sequence_length, max_target_sequence_length, 
                                    dense_layer, keep_prob)
        scope.reuse_variables()
        inf_decoder_output = decoding_layer_infer(
                                    encoder_state, stacked_cell, dec_embeddings,
                                    target_vocab_to_int['<GO>'], target_vocab_to_int['<EOS>'],
                                    max_target_sequence_length, target_vocab_size,
                                    dense_layer, batch_size, keep_prob)
    return tr_decoder_output, inf_decoder_output



"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_decoding_layer(decoding_layer)
# Out:
# Tests Passed

# %% [markdown]
# ### Build the Neural Network
# Apply the functions you implemented above to:
#
# - Encode the input using your `encoding_layer(rnn_inputs, rnn_size, num_layers, keep_prob,  source_sequence_length, source_vocab_size, encoding_embedding_size)`.
# - Process target data using your `process_decoder_input(target_data, target_vocab_to_int, batch_size)` function.
# - Decode the encoded input using your `decoding_layer(dec_input, enc_state, target_sequence_length, max_target_sentence_length, rnn_size, num_layers, target_vocab_to_int, target_vocab_size, batch_size, keep_prob, dec_embedding_size)` function.

# %%
def seq2seq_model(input_data, target_data, keep_prob, batch_size,
                  source_sequence_length, target_sequence_length,
                  max_target_sentence_length,
                  source_vocab_size, target_vocab_size,
                  enc_embedding_size, dec_embedding_size,
                  rnn_size, num_layers, target_vocab_to_int):
    """
    Build the Sequence-to-Sequence part of the neural network
    :param input_data: Input placeholder
    :param target_data: Target placeholder
    :param keep_prob: Dropout keep probability placeholder
    :param batch_size: Batch Size
    :param source_sequence_length: Sequence Lengths of source sequences in the batch
    :param target_sequence_length: Sequence Lengths of target sequences in the batch
    :param source_vocab_size: Source vocabulary size
    :param target_vocab_size: Target vocabulary size
    :param enc_embedding_size: Decoder embedding size
    :param dec_embedding_size: Encoder embedding size
    :param rnn_size: RNN Size
    :param num_layers: Number of layers
    :param target_vocab_to_int: Dictionary to go from the target words to an id
    :return: Tuple of (Training BasicDecoderOutput, Inference BasicDecoderOutput)
    """
    # TODO: Implement Function
    output, state = encoding_layer(input_data, rnn_size, num_layers, keep_prob, 
                                       source_sequence_length, source_vocab_size, enc_embedding_size)
    proc_input = process_decoder_input(target_data, target_vocab_to_int, batch_size)
    tr_dec_output, inf_dec_output = decoding_layer(
                                        proc_input, state, target_sequence_length, max_target_sentence_length,
                                        rnn_size, num_layers, target_vocab_to_int, target_vocab_size,
                                        batch_size, keep_prob, dec_embedding_size)
    return tr_dec_output, inf_dec_output


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_seq2seq_model(seq2seq_model)
# Out:
# Tests Passed

# %% [markdown]
# ## Neural Network Training
# ### Hyperparameters
# Tune the following parameters:
#
# - Set `epochs` to the number of epochs.
# - Set `batch_size` to the batch size.
# - Set `rnn_size` to the size of the RNNs.
# - Set `num_layers` to the number of layers.
# - Set `encoding_embedding_size` to the size of the embedding for the encoder.
# - Set `decoding_embedding_size` to the size of the embedding for the decoder.
# - Set `learning_rate` to the learning rate.
# - Set `keep_probability` to the Dropout keep probability
# - Set `display_step` to state how many steps between each debug output statement

# %%
# Number of Epochs
epochs = 10
# Batch Size
batch_size = 512
# RNN Size
rnn_size = 128
# Number of Layers
num_layers = 2
# Embedding Size
encoding_embedding_size = 128
decoding_embedding_size = 128
# Learning Rate
learning_rate = 0.001
# Dropout Keep Probability
keep_probability = 0.55
display_step = True

# %% [markdown]
# ### Build the Graph
# Build the graph using the neural network you implemented.

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
save_path = 'checkpoints/dev'
(source_int_text, target_int_text), (source_vocab_to_int, target_vocab_to_int), _ = helper.load_preprocess()
max_target_sentence_length = max([len(sentence) for sentence in source_int_text])

train_graph = tf.Graph()
with train_graph.as_default():
    input_data, targets, lr, keep_prob, target_sequence_length, max_target_sequence_length, source_sequence_length = model_inputs()

    #sequence_length = tf.placeholder_with_default(max_target_sentence_length, None, name='sequence_length')
    input_shape = tf.shape(input_data)

    train_logits, inference_logits = seq2seq_model(tf.reverse(input_data, [-1]),
                                                   targets,
                                                   keep_prob,
                                                   batch_size,
                                                   source_sequence_length,
                                                   target_sequence_length,
                                                   max_target_sequence_length,
                                                   len(source_vocab_to_int),
                                                   len(target_vocab_to_int),
                                                   encoding_embedding_size,
                                                   decoding_embedding_size,
                                                   rnn_size,
                                                   num_layers,
                                                   target_vocab_to_int)


    training_logits = tf.identity(train_logits.rnn_output, name='logits')
    inference_logits = tf.identity(inference_logits.sample_id, name='predictions')

    masks = tf.sequence_mask(target_sequence_length, max_target_sequence_length, dtype=tf.float32, name='masks')

    with tf.name_scope("optimization"):
        # Loss function
        cost = tf.contrib.seq2seq.sequence_loss(
            training_logits,
            targets,
            masks)

        # Optimizer
        optimizer = tf.train.AdamOptimizer(lr)

        # Gradient Clipping
        gradients = optimizer.compute_gradients(cost)
        capped_gradients = [(tf.clip_by_value(grad, -1., 1.), var) for grad, var in gradients if grad is not None]
        train_op = optimizer.apply_gradients(capped_gradients)

# %% [markdown]
# Batch and pad the source and target sequences

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
def pad_sentence_batch(sentence_batch, pad_int):
    """Pad sentences with <PAD> so that each sentence of a batch has the same length"""
    max_sentence = max([len(sentence) for sentence in sentence_batch])
    return [sentence + [pad_int] * (max_sentence - len(sentence)) for sentence in sentence_batch]


def get_batches(sources, targets, batch_size, source_pad_int, target_pad_int):
    """Batch targets, sources, and the lengths of their sentences together"""
    for batch_i in range(0, len(sources)//batch_size):
        start_i = batch_i * batch_size

        # Slice the right amount for the batch
        sources_batch = sources[start_i:start_i + batch_size]
        targets_batch = targets[start_i:start_i + batch_size]

        # Pad
        pad_sources_batch = np.array(pad_sentence_batch(sources_batch, source_pad_int))
        pad_targets_batch = np.array(pad_sentence_batch(targets_batch, target_pad_int))

        # Need the lengths for the _lengths parameters
        pad_targets_lengths = []
        for target in pad_targets_batch:
            pad_targets_lengths.append(len(target))

        pad_source_lengths = []
        for source in pad_sources_batch:
            pad_source_lengths.append(len(source))

        yield pad_sources_batch, pad_targets_batch, pad_source_lengths, pad_targets_lengths

# %% [markdown]
# ### Train
# Train the neural network on the preprocessed data. If you have a hard time getting a good loss, check the forms to see if anyone is having the same problem.

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
def get_accuracy(target, logits):
    """
    Calculate accuracy
    """
    max_seq = max(target.shape[1], logits.shape[1])
    if max_seq - target.shape[1]:
        target = np.pad(
            target,
            [(0,0),(0,max_seq - target.shape[1])],
            'constant')
    if max_seq - logits.shape[1]:
        logits = np.pad(
            logits,
            [(0,0),(0,max_seq - logits.shape[1])],
            'constant')

    return np.mean(np.equal(target, logits))

# Split data to training and validation sets
train_source = source_int_text[batch_size:]
train_target = target_int_text[batch_size:]
valid_source = source_int_text[:batch_size]
valid_target = target_int_text[:batch_size]
(valid_sources_batch, valid_targets_batch, valid_sources_lengths, valid_targets_lengths ) = next(get_batches(valid_source,
                                                                                                             valid_target,
                                                                                                             batch_size,
                                                                                                             source_vocab_to_int['<PAD>'],
                                                                                                             target_vocab_to_int['<PAD>']))                                                                                                  
with tf.Session(graph=train_graph) as sess:
    sess.run(tf.global_variables_initializer())

    for epoch_i in range(epochs):
        for batch_i, (source_batch, target_batch, sources_lengths, targets_lengths) in enumerate(
                get_batches(train_source, train_target, batch_size,
                            source_vocab_to_int['<PAD>'],
                            target_vocab_to_int['<PAD>'])):

            _, loss = sess.run(
                [train_op, cost],
                {input_data: source_batch,
                 targets: target_batch,
                 lr: learning_rate,
                 target_sequence_length: targets_lengths,
                 source_sequence_length: sources_lengths,
                 keep_prob: keep_probability})


            if batch_i % display_step == 0 and batch_i > 0:


                batch_train_logits = sess.run(
                    inference_logits,
                    {input_data: source_batch,
                     source_sequence_length: sources_lengths,
                     target_sequence_length: targets_lengths,
                     keep_prob: 1.0})


                batch_valid_logits = sess.run(
                    inference_logits,
                    {input_data: valid_sources_batch,
                     source_sequence_length: valid_sources_lengths,
                     target_sequence_length: valid_targets_lengths,
                     keep_prob: 1.0})

                train_acc = get_accuracy(target_batch, batch_train_logits)

                valid_acc = get_accuracy(valid_targets_batch, batch_valid_logits)

                print('Epoch {:>3} Batch {:>4}/{} - Train Accuracy: {:>6.4f}, Validation Accuracy: {:>6.4f}, Loss: {:>6.4f}'
                      .format(epoch_i, batch_i, len(source_int_text) // batch_size, train_acc, valid_acc, loss))

    # Save Model
    saver = tf.train.Saver()
    saver.save(sess, save_path)
    print('Model Trained and Saved')
# Out:
# Epoch   0 Batch    1/269 - Train Accuracy: 0.2329, Validation Accuracy: 0.3096, Loss: 5.6892
# Epoch   0 Batch    2/269 - Train Accuracy: 0.2655, Validation Accuracy: 0.3096, Loss: 5.4863
# Epoch   0 Batch    3/269 - Train Accuracy: 0.2444, Validation Accuracy: 0.3096, Loss: 5.3436
# Epoch   0 Batch    4/269 - Train Accuracy: 0.2317, Validation Accuracy: 0.3096, Loss: 5.1935
# Epoch   0 Batch    5/269 - Train Accuracy: 0.2325, Validation Accuracy: 0.3096, Loss: 5.0299
# Epoch   0 Batch    6/269 - Train Accuracy: 0.2884, Validation Accuracy: 0.3199, Loss: 4.7039
# Epoch   0 Batch    7/269 - Train Accuracy: 0.2877, Validation Accuracy: 0.3220, Loss: 4.5887
# Epoch   0 Batch    8/269 - Train Accuracy: 0.2577, Validation Accuracy: 0.3251, Loss: 4.6622
# Epoch   0 Batch    9/269 - Train Accuracy: 0.2986, Validation Accuracy: 0.3399, Loss: 4.4505
# Epoch   0 Batch   10/269 - Train Accuracy: 0.2680, Validation Accuracy: 0.3411, Loss: 4.5145
# Epoch   0 Batch   11/269 - Train Accuracy: 0.3065, Validation Accuracy: 0.3421, Loss: 4.2225
# Epoch   0 Batch   12/269 - Train Accuracy: 0.2806, Validation Accuracy: 0.3426, Loss: 4.2593
# Epoch   0 Batch   13/269 - Train Accuracy: 0.3457, Validation Accuracy: 0.3441, Loss: 3.8845
# Epoch   0 Batch   14/269 - Train Accuracy: 0.3060, Validation Accuracy: 0.3446, Loss: 3.9931
# Epoch   0 Batch   15/269 - Train Accuracy: 0.2976, Validation Accuracy: 0.3446, Loss: 3.9244
# Epoch   0 Batch   16/269 - Train Accuracy: 0.3129, Validation Accuracy: 0.3445, Loss: 3.7854
# Epoch   0 Batch   17/269 - Train Accuracy: 0.3075, Validation Accuracy: 0.3491, Loss: 3.7421
# Epoch   0 Batch   18/269 - Train Accuracy: 0.2880, Validation Accuracy: 0.3588, Loss: 3.8157
# Epoch   0 Batch   19/269 - Train Accuracy: 0.3562, Validation Accuracy: 0.3578, Loss: 3.4485
# Epoch   0 Batch   20/269 - Train Accuracy: 0.2921, Validation Accuracy: 0.3582, Loss: 3.6734
# Epoch   0 Batch   21/269 - Train Accuracy: 0.3046, Validation Accuracy: 0.3688, Loss: 3.6316
# Epoch   0 Batch   22/269 - Train Accuracy: 0.3544, Validation Accuracy: 0.3817, Loss: 3.4063
# Epoch   0 Batch   23/269 - Train Accuracy: 0.3635, Validation Accuracy: 0.3816, Loss: 3.3485
# Epoch   0 Batch   24/269 - Train Accuracy: 0.3101, Validation Accuracy: 0.3779, Loss: 3.5165
# Epoch   0 Batch   25/269 - Train Accuracy: 0.3212, Validation Accuracy: 0.3847, Loss: 3.4622
# Epoch   0 Batch   26/269 - Train Accuracy: 0.3936, Validation Accuracy: 0.3909, Loss: 3.1333
# Epoch   0 Batch   27/269 - Train Accuracy: 0.3672, Validation Accuracy: 0.4001, Loss: 3.2634
# Epoch   0 Batch   28/269 - Train Accuracy: 0.3324, Validation Accuracy: 0.4064, Loss: 3.4238
# Epoch   0 Batch   29/269 - Train Accuracy: 0.3407, Validation Accuracy: 0.4037, Loss: 3.3426
# Epoch   0 Batch   30/269 - Train Accuracy: 0.3679, Validation Accuracy: 0.4055, Loss: 3.1838
# Epoch   0 Batch   31/269 - Train Accuracy: 0.3819, Validation Accuracy: 0.4072, Loss: 3.1307
# Epoch   0 Batch   32/269 - Train Accuracy: 0.3747, Validation Accuracy: 0.4109, Loss: 3.1550
# Epoch   0 Batch   33/269 - Train Accuracy: 0.3730, Validation Accuracy: 0.4006, Loss: 3.0545
# Epoch   0 Batch   34/269 - Train Accuracy: 0.3731, Validation Accuracy: 0.4038, Loss: 3.0683
# Epoch   0 Batch   35/269 - Train Accuracy: 0.3899, Validation Accuracy: 0.4162, Loss: 3.0344
# Epoch   0 Batch   36/269 - Train Accuracy: 0.3903, Validation Accuracy: 0.4202, Loss: 3.0332
# Epoch   0 Batch   37/269 - Train Accuracy: 0.3898, Validation Accuracy: 0.4136, Loss: 3.0006
# Epoch   0 Batch   38/269 - Train Accuracy: 0.3981, Validation Accuracy: 0.4287, Loss: 3.0072
# Epoch   0 Batch   39/269 - Train Accuracy: 0.3957, Validation Accuracy: 0.4294, Loss: 2.9778
# Epoch   0 Batch   40/269 - Train Accuracy: 0.3657, Validation Accuracy: 0.4248, Loss: 3.0835
# Epoch   0 Batch   41/269 - Train Accuracy: 0.3950, Validation Accuracy: 0.4294, Loss: 2.9447
# Epoch   0 Batch   42/269 - Train Accuracy: 0.4244, Validation Accuracy: 0.4290, Loss: 2.8029
# Epoch   0 Batch   43/269 - Train Accuracy: 0.3779, Validation Accuracy: 0.4319, Loss: 3.0095
# Epoch   0 Batch   44/269 - Train Accuracy: 0.4174, Validation Accuracy: 0.4394, Loss: 2.8727
# Epoch   0 Batch   45/269 - Train Accuracy: 0.3827, Validation Accuracy: 0.4355, Loss: 2.9994
# Epoch   0 Batch   46/269 - Train Accuracy: 0.3746, Validation Accuracy: 0.4379, Loss: 3.0308
# Epoch   0 Batch   47/269 - Train Accuracy: 0.4397, Validation Accuracy: 0.4352, Loss: 2.7014
# Epoch   0 Batch   48/269 - Train Accuracy: 0.4220, Validation Accuracy: 0.4444, Loss: 2.8076
# Epoch   0 Batch   49/269 - Train Accuracy: 0.3926, Validation Accuracy: 0.4523, Loss: 2.9206
# Epoch   0 Batch   50/269 - Train Accuracy: 0.3860, Validation Accuracy: 0.4395, Loss: 2.9208
# Epoch   0 Batch   51/269 - Train Accuracy: 0.4134, Validation Accuracy: 0.4495, Loss: 2.8181
# Epoch   0 Batch   52/269 - Train Accuracy: 0.4221, Validation Accuracy: 0.4447, Loss: 2.7707
# Epoch   0 Batch   53/269 - Train Accuracy: 0.3958, Validation Accuracy: 0.4465, Loss: 2.8810
# Epoch   0 Batch   54/269 - Train Accuracy: 0.4006, Validation Accuracy: 0.4537, Loss: 2.8751
# Epoch   0 Batch   55/269 - Train Accuracy: 0.4130, Validation Accuracy: 0.4387, Loss: 2.7441
# Epoch   0 Batch   56/269 - Train Accuracy: 0.4294, Validation Accuracy: 0.4537, Loss: 2.7273
# Epoch   0 Batch   57/269 - Train Accuracy: 0.4285, Validation Accuracy: 0.4540, Loss: 2.7023
# Epoch   0 Batch   58/269 - Train Accuracy: 0.4154, Validation Accuracy: 0.4363, Loss: 2.6931
# Epoch   0 Batch   59/269 - Train Accuracy: 0.4204, Validation Accuracy: 0.4530, Loss: 2.6978
# Epoch   0 Batch   60/269 - Train Accuracy: 0.4359, Validation Accuracy: 0.4547, Loss: 2.6192
# Epoch   0 Batch   61/269 - Train Accuracy: 0.4458, Validation Accuracy: 0.4409, Loss: 2.5394
# Epoch   0 Batch   62/269 - Train Accuracy: 0.4523, Validation Accuracy: 0.4561, Loss: 2.5674
# Epoch   0 Batch   63/269 - Train Accuracy: 0.4306, Validation Accuracy: 0.4580, Loss: 2.6332
# Epoch   0 Batch   64/269 - Train Accuracy: 0.4195, Validation Accuracy: 0.4487, Loss: 2.6488
# Epoch   0 Batch   65/269 - Train Accuracy: 0.4386, Validation Accuracy: 0.4625, Loss: 2.6210
# Epoch   0 Batch   66/269 - Train Accuracy: 0.4600, Validation Accuracy: 0.4685, Loss: 2.5413
# Epoch   0 Batch   67/269 - Train Accuracy: 0.4226, Validation Accuracy: 0.4498, Loss: 2.6180
# Epoch   0 Batch   68/269 - Train Accuracy: 0.4405, Validation Accuracy: 0.4682, Loss: 2.6160
# Epoch   0 Batch   69/269 - Train Accuracy: 0.4133, Validation Accuracy: 0.4684, Loss: 2.7479
# Epoch   0 Batch   70/269 - Train Accuracy: 0.4433, Validation Accuracy: 0.4659, Loss: 2.5689
# Epoch   0 Batch   71/269 - Train Accuracy: 0.4255, Validation Accuracy: 0.4717, Loss: 2.6952
# Epoch   0 Batch   72/269 - Train Accuracy: 0.4660, Validation Accuracy: 0.4730, Loss: 2.4800
# Epoch   0 Batch   73/269 - Train Accuracy: 0.4539, Validation Accuracy: 0.4731, Loss: 2.5536
# Epoch   0 Batch   74/269 - Train Accuracy: 0.4280, Validation Accuracy: 0.4663, Loss: 2.6203
# Epoch   0 Batch   75/269 - Train Accuracy: 0.4400, Validation Accuracy: 0.4631, Loss: 2.5368
# Epoch   0 Batch   76/269 - Train Accuracy: 0.4385, Validation Accuracy: 0.4721, Loss: 2.5913
# Epoch   0 Batch   77/269 - Train Accuracy: 0.4498, Validation Accuracy: 0.4656, Loss: 2.5227
# Epoch   0 Batch   78/269 - Train Accuracy: 0.4491, Validation Accuracy: 0.4751, Loss: 2.5570
# Epoch   0 Batch   79/269 - Train Accuracy: 0.4488, Validation Accuracy: 0.4749, Loss: 2.5134
# Epoch   0 Batch   80/269 - Train Accuracy: 0.4582, Validation Accuracy: 0.4739, Loss: 2.4445
# Epoch   0 Batch   81/269 - Train Accuracy: 0.4562, Validation Accuracy: 0.4767, Loss: 2.5041
# Epoch   0 Batch   82/269 - Train Accuracy: 0.4602, Validation Accuracy: 0.4706, Loss: 2.4325
# Epoch   0 Batch   83/269 - Train Accuracy: 0.4559, Validation Accuracy: 0.4744, Loss: 2.4312
# Epoch   0 Batch   84/269 - Train Accuracy: 0.4570, Validation Accuracy: 0.4735, Loss: 2.4764
# Epoch   0 Batch   85/269 - Train Accuracy: 0.4489, Validation Accuracy: 0.4767, Loss: 2.4861
# Epoch   0 Batch   86/269 - Train Accuracy: 0.4406, Validation Accuracy: 0.4651, Loss: 2.4731
# Epoch   0 Batch   87/269 - Train Accuracy: 0.4170, Validation Accuracy: 0.4781, Loss: 2.6274
# Epoch   0 Batch   88/269 - Train Accuracy: 0.4645, Validation Accuracy: 0.4801, Loss: 2.4243
# Epoch   0 Batch   89/269 - Train Accuracy: 0.4664, Validation Accuracy: 0.4800, Loss: 2.4142
# Epoch   0 Batch   90/269 - Train Accuracy: 0.4178, Validation Accuracy: 0.4772, Loss: 2.5496
# Epoch   0 Batch   91/269 - Train Accuracy: 0.4531, Validation Accuracy: 0.4749, Loss: 2.3981
# Epoch   0 Batch   92/269 - Train Accuracy: 0.4551, Validation Accuracy: 0.4775, Loss: 2.4014
# Epoch   0 Batch   93/269 - Train Accuracy: 0.4788, Validation Accuracy: 0.4799, Loss: 2.3030
# Epoch   0 Batch   94/269 - Train Accuracy: 0.4556, Validation Accuracy: 0.4809, Loss: 2.3947
# Epoch   0 Batch   95/269 - Train Accuracy: 0.4604, Validation Accuracy: 0.4779, Loss: 2.3893
# Epoch   0 Batch   96/269 - Train Accuracy: 0.4552, Validation Accuracy: 0.4798, Loss: 2.3881
# Epoch   0 Batch   97/269 - Train Accuracy: 0.4528, Validation Accuracy: 0.4748, Loss: 2.3695
# Epoch   0 Batch   98/269 - Train Accuracy: 0.4784, Validation Accuracy: 0.4869, Loss: 2.3198
# Epoch   0 Batch   99/269 - Train Accuracy: 0.4369, Validation Accuracy: 0.4862, Loss: 2.4698
# Epoch   0 Batch  100/269 - Train Accuracy: 0.4831, Validation Accuracy: 0.4862, Loss: 2.2765
# Epoch   0 Batch  101/269 - Train Accuracy: 0.4366, Validation Accuracy: 0.4841, Loss: 2.4474
# Epoch   0 Batch  102/269 - Train Accuracy: 0.4521, Validation Accuracy: 0.4760, Loss: 2.3216
# Epoch   0 Batch  103/269 - Train Accuracy: 0.4473, Validation Accuracy: 0.4727, Loss: 2.3121
# Epoch   0 Batch  104/269 - Train Accuracy: 0.4528, Validation Accuracy: 0.4771, Loss: 2.3339
# Epoch   0 Batch  105/269 - Train Accuracy: 0.4521, Validation Accuracy: 0.4819, Loss: 2.3519
# Epoch   0 Batch  106/269 - Train Accuracy: 0.4576, Validation Accuracy: 0.4901, Loss: 2.3222
# Epoch   0 Batch  107/269 - Train Accuracy: 0.4177, Validation Accuracy: 0.4736, Loss: 2.4096
# Epoch   0 Batch  108/269 - Train Accuracy: 0.4479, Validation Accuracy: 0.4764, Loss: 2.3183
# Epoch   0 Batch  109/269 - Train Accuracy: 0.4541, Validation Accuracy: 0.4891, Loss: 2.3091
# Epoch   0 Batch  110/269 - Train Accuracy: 0.4581, Validation Accuracy: 0.4777, Loss: 2.2605
# Epoch   0 Batch  111/269 - Train Accuracy: 0.4365, Validation Accuracy: 0.4936, Loss: 2.4252
# Epoch   0 Batch  112/269 - Train Accuracy: 0.4651, Validation Accuracy: 0.4912, Loss: 2.2483
# Epoch   0 Batch  113/269 - Train Accuracy: 0.4753, Validation Accuracy: 0.4790, Loss: 2.1512
# Epoch   0 Batch  114/269 - Train Accuracy: 0.4673, Validation Accuracy: 0.4929, Loss: 2.2540
# Epoch   0 Batch  115/269 - Train Accuracy: 0.4284, Validation Accuracy: 0.4867, Loss: 2.3189
# Epoch   0 Batch  116/269 - Train Accuracy: 0.4780, Validation Accuracy: 0.4949, Loss: 2.2421
# Epoch   0 Batch  117/269 - Train Accuracy: 0.4574, Validation Accuracy: 0.4819, Loss: 2.2090
# Epoch   0 Batch  118/269 - Train Accuracy: 0.4888, Validation Accuracy: 0.4946, Loss: 2.1639
# Epoch   0 Batch  119/269 - Train Accuracy: 0.4477, Validation Accuracy: 0.4862, Loss: 2.2728
# Epoch   0 Batch  120/269 - Train Accuracy: 0.4471, Validation Accuracy: 0.4917, Loss: 2.2809
# Epoch   0 Batch  121/269 - Train Accuracy: 0.4706, Validation Accuracy: 0.4933, Loss: 2.1694
# Epoch   0 Batch  122/269 - Train Accuracy: 0.4680, Validation Accuracy: 0.4871, Loss: 2.1283
# Epoch   0 Batch  123/269 - Train Accuracy: 0.4371, Validation Accuracy: 0.4957, Loss: 2.2688
# Epoch   0 Batch  124/269 - Train Accuracy: 0.4740, Validation Accuracy: 0.4954, Loss: 2.1298
# Epoch   0 Batch  125/269 - Train Accuracy: 0.4646, Validation Accuracy: 0.4959, Loss: 2.1195
# Epoch   0 Batch  126/269 - Train Accuracy: 0.4585, Validation Accuracy: 0.4794, Loss: 2.0822
# Epoch   0 Batch  127/269 - Train Accuracy: 0.4380, Validation Accuracy: 0.4877, Loss: 2.2077
# Epoch   0 Batch  128/269 - Train Accuracy: 0.4807, Validation Accuracy: 0.4955, Loss: 2.0915
# Epoch   0 Batch  129/269 - Train Accuracy: 0.4689, Validation Accuracy: 0.4923, Loss: 2.1063
# Epoch   0 Batch  130/269 - Train Accuracy: 0.4160, Validation Accuracy: 0.4766, Loss: 2.2227
# Epoch   0 Batch  131/269 - Train Accuracy: 0.4414, Validation Accuracy: 0.4839, Loss: 2.1525
# Epoch   0 Batch  132/269 - Train Accuracy: 0.4480, Validation Accuracy: 0.4780, Loss: 2.0846
# Epoch   0 Batch  133/269 - Train Accuracy: 0.4468, Validation Accuracy: 0.4769, Loss: 2.0483
# Epoch   0 Batch  134/269 - Train Accuracy: 0.4263, Validation Accuracy: 0.4840, Loss: 2.1175
# Epoch   0 Batch  135/269 - Train Accuracy: 0.4404, Validation Accuracy: 0.4980, Loss: 2.1629
# Epoch   0 Batch  136/269 - Train Accuracy: 0.4258, Validation Accuracy: 0.4840, Loss: 2.1509
# Epoch   0 Batch  137/269 - Train Accuracy: 0.4336, Validation Accuracy: 0.4799, Loss: 2.1170
# Epoch   0 Batch  138/269 - Train Accuracy: 0.4354, Validation Accuracy: 0.4859, Loss: 2.0648
# Epoch   0 Batch  139/269 - Train Accuracy: 0.4662, Validation Accuracy: 0.4842, Loss: 1.9810
# Epoch   0 Batch  140/269 - Train Accuracy: 0.4574, Validation Accuracy: 0.4822, Loss: 1.9930
# Epoch   0 Batch  141/269 - Train Accuracy: 0.4563, Validation Accuracy: 0.4970, Loss: 2.0273
# Epoch   0 Batch  142/269 - Train Accuracy: 0.4749, Validation Accuracy: 0.4925, Loss: 1.9605
# Epoch   0 Batch  143/269 - Train Accuracy: 0.4624, Validation Accuracy: 0.4831, Loss: 1.9568
# Epoch   0 Batch  144/269 - Train Accuracy: 0.4741, Validation Accuracy: 0.4919, Loss: 1.9360
# Epoch   0 Batch  145/269 - Train Accuracy: 0.4568, Validation Accuracy: 0.4883, Loss: 1.9611
# Epoch   0 Batch  146/269 - Train Accuracy: 0.4682, Validation Accuracy: 0.4868, Loss: 1.9245
# Epoch   0 Batch  147/269 - Train Accuracy: 0.4893, Validation Accuracy: 0.4863, Loss: 1.8630
# Epoch   0 Batch  148/269 - Train Accuracy: 0.4633, Validation Accuracy: 0.4930, Loss: 1.9726
# Epoch   0 Batch  149/269 - Train Accuracy: 0.4599, Validation Accuracy: 0.4837, Loss: 1.9134
# Epoch   0 Batch  150/269 - Train Accuracy: 0.4679, Validation Accuracy: 0.4931, Loss: 1.9136
# Epoch   0 Batch  151/269 - Train Accuracy: 0.5031, Validation Accuracy: 0.4993, Loss: 1.8171
# Epoch   0 Batch  152/269 - Train Accuracy: 0.4592, Validation Accuracy: 0.4893, Loss: 1.9081
# Epoch   0 Batch  153/269 - Train Accuracy: 0.4757, Validation Accuracy: 0.4972, Loss: 1.8852
# Epoch   0 Batch  154/269 - Train Accuracy: 0.4456, Validation Accuracy: 0.4958, Loss: 1.9832
# Epoch   0 Batch  155/269 - Train Accuracy: 0.4837, Validation Accuracy: 0.4828, Loss: 1.7672
# Epoch   0 Batch  156/269 - Train Accuracy: 0.4560, Validation Accuracy: 0.4940, Loss: 1.9233
# Epoch   0 Batch  157/269 - Train Accuracy: 0.4664, Validation Accuracy: 0.4941, Loss: 1.8662
# Epoch   0 Batch  158/269 - Train Accuracy: 0.4524, Validation Accuracy: 0.4828, Loss: 1.8337
# Epoch   0 Batch  159/269 - Train Accuracy: 0.4735, Validation Accuracy: 0.4992, Loss: 1.8580
# Epoch   0 Batch  160/269 - Train Accuracy: 0.4658, Validation Accuracy: 0.4871, Loss: 1.8532
# Epoch   0 Batch  161/269 - Train Accuracy: 0.4432, Validation Accuracy: 0.4782, Loss: 1.8508
# Epoch   0 Batch  162/269 - Train Accuracy: 0.4774, Validation Accuracy: 0.4991, Loss: 1.8257
# Epoch   0 Batch  163/269 - Train Accuracy: 0.4684, Validation Accuracy: 0.4871, Loss: 1.8231
# Epoch   0 Batch  164/269 - Train Accuracy: 0.4663, Validation Accuracy: 0.4901, Loss: 1.8195
# Epoch   0 Batch  165/269 - Train Accuracy: 0.4423, Validation Accuracy: 0.4965, Loss: 1.8716
# Epoch   0 Batch  166/269 - Train Accuracy: 0.4897, Validation Accuracy: 0.4840, Loss: 1.7076
# Epoch   0 Batch  167/269 - Train Accuracy: 0.4678, Validation Accuracy: 0.4878, Loss: 1.7854
# Epoch   0 Batch  168/269 - Train Accuracy: 0.4800, Validation Accuracy: 0.5020, Loss: 1.8046
# Epoch   0 Batch  169/269 - Train Accuracy: 0.4526, Validation Accuracy: 0.4830, Loss: 1.7905
# Epoch   0 Batch  170/269 - Train Accuracy: 0.4628, Validation Accuracy: 0.4830, Loss: 1.7702
# Epoch   0 Batch  171/269 - Train Accuracy: 0.4585, Validation Accuracy: 0.5019, Loss: 1.8293
# Epoch   0 Batch  172/269 - Train Accuracy: 0.4670, Validation Accuracy: 0.4909, Loss: 1.7725
# Epoch   0 Batch  173/269 - Train Accuracy: 0.4669, Validation Accuracy: 0.4933, Loss: 1.7536
# Epoch   0 Batch  174/269 - Train Accuracy: 0.4688, Validation Accuracy: 0.5031, Loss: 1.7652
# Epoch   0 Batch  175/269 - Train Accuracy: 0.4615, Validation Accuracy: 0.4832, Loss: 1.7606
# Epoch   0 Batch  176/269 - Train Accuracy: 0.4455, Validation Accuracy: 0.4874, Loss: 1.8245
# Epoch   0 Batch  177/269 - Train Accuracy: 0.4885, Validation Accuracy: 0.4976, Loss: 1.6843
# Epoch   0 Batch  178/269 - Train Accuracy: 0.4429, Validation Accuracy: 0.4841, Loss: 1.8029
# Epoch   0 Batch  179/269 - Train Accuracy: 0.4657, Validation Accuracy: 0.4893, Loss: 1.7259
# Epoch   0 Batch  180/269 - Train Accuracy: 0.4764, Validation Accuracy: 0.4995, Loss: 1.7099
# Epoch   0 Batch  181/269 - Train Accuracy: 0.4628, Validation Accuracy: 0.4807, Loss: 1.7135
# Epoch   0 Batch  182/269 - Train Accuracy: 0.4751, Validation Accuracy: 0.4905, Loss: 1.7176
# Epoch   0 Batch  183/269 - Train Accuracy: 0.5496, Validation Accuracy: 0.5043, Loss: 1.4826
# Epoch   0 Batch  184/269 - Train Accuracy: 0.4307, Validation Accuracy: 0.4830, Loss: 1.7756
# Epoch   0 Batch  185/269 - Train Accuracy: 0.4815, Validation Accuracy: 0.4882, Loss: 1.6777
# Epoch   0 Batch  186/269 - Train Accuracy: 0.4531, Validation Accuracy: 0.5036, Loss: 1.7587
# Epoch   0 Batch  187/269 - Train Accuracy: 0.4684, Validation Accuracy: 0.4855, Loss: 1.6540
# Epoch   0 Batch  188/269 - Train Accuracy: 0.4720, Validation Accuracy: 0.4866, Loss: 1.6366
# Epoch   0 Batch  189/269 - Train Accuracy: 0.4818, Validation Accuracy: 0.5020, Loss: 1.6628
# Epoch   0 Batch  190/269 - Train Accuracy: 0.4776, Validation Accuracy: 0.5057, Loss: 1.6513
# Epoch   0 Batch  191/269 - Train Accuracy: 0.4699, Validation Accuracy: 0.4912, Loss: 1.6739
# Epoch   0 Batch  192/269 - Train Accuracy: 0.4746, Validation Accuracy: 0.4926, Loss: 1.6771
# Epoch   0 Batch  193/269 - Train Accuracy: 0.4780, Validation Accuracy: 0.5028, Loss: 1.6508
# Epoch   0 Batch  194/269 - Train Accuracy: 0.4645, Validation Accuracy: 0.4914, Loss: 1.6540
# Epoch   0 Batch  195/269 - Train Accuracy: 0.4555, Validation Accuracy: 0.4961, Loss: 1.6697
# Epoch   0 Batch  196/269 - Train Accuracy: 0.4733, Validation Accuracy: 0.5036, Loss: 1.6367
# Epoch   0 Batch  197/269 - Train Accuracy: 0.4284, Validation Accuracy: 0.4885, Loss: 1.7080
# Epoch   0 Batch  198/269 - Train Accuracy: 0.4457, Validation Accuracy: 0.4964, Loss: 1.7387
# Epoch   0 Batch  199/269 - Train Accuracy: 0.4815, Validation Accuracy: 0.5092, Loss: 1.6656
# Epoch   0 Batch  200/269 - Train Accuracy: 0.4448, Validation Accuracy: 0.4879, Loss: 1.6781
# Epoch   0 Batch  201/269 - Train Accuracy: 0.4659, Validation Accuracy: 0.4893, Loss: 1.6302
# Epoch   0 Batch  202/269 - Train Accuracy: 0.4883, Validation Accuracy: 0.5144, Loss: 1.6305
# Epoch   0 Batch  203/269 - Train Accuracy: 0.4502, Validation Accuracy: 0.5025, Loss: 1.6893
# Epoch   0 Batch  204/269 - Train Accuracy: 0.4319, Validation Accuracy: 0.4869, Loss: 1.6616
# Epoch   0 Batch  205/269 - Train Accuracy: 0.4673, Validation Accuracy: 0.5018, Loss: 1.6120
# Epoch   0 Batch  206/269 - Train Accuracy: 0.4491, Validation Accuracy: 0.5020, Loss: 1.6914
# Epoch   0 Batch  207/269 - Train Accuracy: 0.4795, Validation Accuracy: 0.4911, Loss: 1.5305
# Epoch   0 Batch  208/269 - Train Accuracy: 0.4549, Validation Accuracy: 0.4986, Loss: 1.6938
# Epoch   0 Batch  209/269 - Train Accuracy: 0.4549, Validation Accuracy: 0.5093, Loss: 1.6521
# Epoch   0 Batch  210/269 - Train Accuracy: 0.4758, Validation Accuracy: 0.4998, Loss: 1.5684
# Epoch   0 Batch  211/269 - Train Accuracy: 0.4653, Validation Accuracy: 0.4978, Loss: 1.5769
# Epoch   0 Batch  212/269 - Train Accuracy: 0.5039, Validation Accuracy: 0.5081, Loss: 1.5364
# Epoch   0 Batch  213/269 - Train Accuracy: 0.4783, Validation Accuracy: 0.5045, Loss: 1.5483
# Epoch   0 Batch  214/269 - Train Accuracy: 0.4811, Validation Accuracy: 0.5023, Loss: 1.5538
# Epoch   0 Batch  215/269 - Train Accuracy: 0.5162, Validation Accuracy: 0.5092, Loss: 1.4630
# Epoch   0 Batch  216/269 - Train Accuracy: 0.4576, Validation Accuracy: 0.5164, Loss: 1.6617
# Epoch   0 Batch  217/269 - Train Accuracy: 0.4582, Validation Accuracy: 0.5070, Loss: 1.6330
# Epoch   0 Batch  218/269 - Train Accuracy: 0.4751, Validation Accuracy: 0.5127, Loss: 1.6244
# Epoch   0 Batch  219/269 - Train Accuracy: 0.4812, Validation Accuracy: 0.5182, Loss: 1.6048
# Epoch   0 Batch  220/269 - Train Accuracy: 0.5016, Validation Accuracy: 0.5085, Loss: 1.4832
# Epoch   0 Batch  221/269 - Train Accuracy: 0.4901, Validation Accuracy: 0.5101, Loss: 1.5312
# Epoch   0 Batch  222/269 - Train Accuracy: 0.4984, Validation Accuracy: 0.5156, Loss: 1.4947
# Epoch   0 Batch  223/269 - Train Accuracy: 0.4874, Validation Accuracy: 0.5091, Loss: 1.4950
# Epoch   0 Batch  224/269 - Train Accuracy: 0.4840, Validation Accuracy: 0.5029, Loss: 1.5338
# Epoch   0 Batch  225/269 - Train Accuracy: 0.4775, Validation Accuracy: 0.5198, Loss: 1.5805
# Epoch   0 Batch  226/269 - Train Accuracy: 0.4900, Validation Accuracy: 0.5179, Loss: 1.5192
# Epoch   0 Batch  227/269 - Train Accuracy: 0.5522, Validation Accuracy: 0.5059, Loss: 1.3205
# Epoch   0 Batch  228/269 - Train Accuracy: 0.4822, Validation Accuracy: 0.5174, Loss: 1.5234
# Epoch   0 Batch  229/269 - Train Accuracy: 0.5074, Validation Accuracy: 0.5242, Loss: 1.4957
# Epoch   0 Batch  230/269 - Train Accuracy: 0.4686, Validation Accuracy: 0.5047, Loss: 1.5255
# Epoch   0 Batch  231/269 - Train Accuracy: 0.4504, Validation Accuracy: 0.5019, Loss: 1.5821
# Epoch   0 Batch  232/269 - Train Accuracy: 0.4565, Validation Accuracy: 0.5163, Loss: 1.5799
# Epoch   0 Batch  233/269 - Train Accuracy: 0.4867, Validation Accuracy: 0.5105, Loss: 1.5183
# Epoch   0 Batch  234/269 - Train Accuracy: 0.4638, Validation Accuracy: 0.5023, Loss: 1.4932
# Epoch   0 Batch  235/269 - Train Accuracy: 0.4951, Validation Accuracy: 0.5148, Loss: 1.5077
# Epoch   0 Batch  236/269 - Train Accuracy: 0.4886, Validation Accuracy: 0.5155, Loss: 1.4857
# Epoch   0 Batch  237/269 - Train Accuracy: 0.4678, Validation Accuracy: 0.4971, Loss: 1.4825
# Epoch   0 Batch  238/269 - Train Accuracy: 0.4870, Validation Accuracy: 0.5071, Loss: 1.4930
# Epoch   0 Batch  239/269 - Train Accuracy: 0.5031, Validation Accuracy: 0.5264, Loss: 1.4583
# Epoch   0 Batch  240/269 - Train Accuracy: 0.5217, Validation Accuracy: 0.5170, Loss: 1.3815
# Epoch   0 Batch  241/269 - Train Accuracy: 0.4819, Validation Accuracy: 0.5158, Loss: 1.4594
# Epoch   0 Batch  242/269 - Train Accuracy: 0.4992, Validation Accuracy: 0.5283, Loss: 1.4630
# Epoch   0 Batch  243/269 - Train Accuracy: 0.5179, Validation Accuracy: 0.5325, Loss: 1.4292
# Epoch   0 Batch  244/269 - Train Accuracy: 0.4890, Validation Accuracy: 0.5231, Loss: 1.4543
# Epoch   0 Batch  245/269 - Train Accuracy: 0.4754, Validation Accuracy: 0.5299, Loss: 1.5333
# Epoch   0 Batch  246/269 - Train Accuracy: 0.5024, Validation Accuracy: 0.5340, Loss: 1.4598
# Epoch   0 Batch  247/269 - Train Accuracy: 0.4827, Validation Accuracy: 0.5255, Loss: 1.5004
# Epoch   0 Batch  248/269 - Train Accuracy: 0.4772, Validation Accuracy: 0.5202, Loss: 1.4417
# Epoch   0 Batch  249/269 - Train Accuracy: 0.5326, Validation Accuracy: 0.5253, Loss: 1.3902
# Epoch   0 Batch  250/269 - Train Accuracy: 0.4875, Validation Accuracy: 0.5210, Loss: 1.4915
# Epoch   0 Batch  251/269 - Train Accuracy: 0.4735, Validation Accuracy: 0.5005, Loss: 1.4253
# Epoch   0 Batch  252/269 - Train Accuracy: 0.4654, Validation Accuracy: 0.5067, Loss: 1.4565
# Epoch   0 Batch  253/269 - Train Accuracy: 0.4838, Validation Accuracy: 0.5107, Loss: 1.4259
# Epoch   0 Batch  254/269 - Train Accuracy: 0.4805, Validation Accuracy: 0.5056, Loss: 1.4085
# Epoch   0 Batch  255/269 - Train Accuracy: 0.5151, Validation Accuracy: 0.5105, Loss: 1.3668
# Epoch   0 Batch  256/269 - Train Accuracy: 0.4741, Validation Accuracy: 0.5167, Loss: 1.4461
# Epoch   0 Batch  257/269 - Train Accuracy: 0.4770, Validation Accuracy: 0.5120, Loss: 1.4352
# Epoch   0 Batch  258/269 - Train Accuracy: 0.4771, Validation Accuracy: 0.5129, Loss: 1.4187
# Epoch   0 Batch  259/269 - Train Accuracy: 0.4993, Validation Accuracy: 0.5154, Loss: 1.4064
# Epoch   0 Batch  260/269 - Train Accuracy: 0.4806, Validation Accuracy: 0.5238, Loss: 1.4823
# Epoch   0 Batch  261/269 - Train Accuracy: 0.4505, Validation Accuracy: 0.5207, Loss: 1.4951
# Epoch   0 Batch  262/269 - Train Accuracy: 0.4991, Validation Accuracy: 0.5178, Loss: 1.4120
# Epoch   0 Batch  263/269 - Train Accuracy: 0.4807, Validation Accuracy: 0.5210, Loss: 1.4569
# Epoch   0 Batch  264/269 - Train Accuracy: 0.4748, Validation Accuracy: 0.5230, Loss: 1.4775
# Epoch   0 Batch  265/269 - Train Accuracy: 0.4698, Validation Accuracy: 0.5168, Loss: 1.4407
# Epoch   0 Batch  266/269 - Train Accuracy: 0.4936, Validation Accuracy: 0.5131, Loss: 1.3750
# Epoch   0 Batch  267/269 - Train Accuracy: 0.4964, Validation Accuracy: 0.5241, Loss: 1.4103
# Epoch   1 Batch    1/269 - Train Accuracy: 0.4506, Validation Accuracy: 0.5147, Loss: 1.4392
# Epoch   1 Batch    2/269 - Train Accuracy: 0.4861, Validation Accuracy: 0.5231, Loss: 1.4107
# Epoch   1 Batch    3/269 - Train Accuracy: 0.4808, Validation Accuracy: 0.5278, Loss: 1.4402
# Epoch   1 Batch    4/269 - Train Accuracy: 0.4628, Validation Accuracy: 0.5186, Loss: 1.4288
# Epoch   1 Batch    5/269 - Train Accuracy: 0.4745, Validation Accuracy: 0.5252, Loss: 1.4363
# Epoch   1 Batch    6/269 - Train Accuracy: 0.5117, Validation Accuracy: 0.5266, Loss: 1.3165
# Epoch   1 Batch    7/269 - Train Accuracy: 0.5010, Validation Accuracy: 0.5147, Loss: 1.3557
# Epoch   1 Batch    8/269 - Train Accuracy: 0.4600, Validation Accuracy: 0.5136, Loss: 1.4143
# Epoch   1 Batch    9/269 - Train Accuracy: 0.4913, Validation Accuracy: 0.5218, Loss: 1.3616
# Epoch   1 Batch   10/269 - Train Accuracy: 0.4688, Validation Accuracy: 0.5190, Loss: 1.3887
# Epoch   1 Batch   11/269 - Train Accuracy: 0.4880, Validation Accuracy: 0.5144, Loss: 1.3614
# Epoch   1 Batch   12/269 - Train Accuracy: 0.4698, Validation Accuracy: 0.5230, Loss: 1.4113
# Epoch   1 Batch   13/269 - Train Accuracy: 0.5284, Validation Accuracy: 0.5227, Loss: 1.2656
# Epoch   1 Batch   14/269 - Train Accuracy: 0.4874, Validation Accuracy: 0.5217, Loss: 1.3273
# Epoch   1 Batch   15/269 - Train Accuracy: 0.4864, Validation Accuracy: 0.5230, Loss: 1.3399
# Epoch   1 Batch   16/269 - Train Accuracy: 0.5074, Validation Accuracy: 0.5203, Loss: 1.3364
# Epoch   1 Batch   17/269 - Train Accuracy: 0.4967, Validation Accuracy: 0.5208, Loss: 1.3056
# Epoch   1 Batch   18/269 - Train Accuracy: 0.4762, Validation Accuracy: 0.5203, Loss: 1.3838
# Epoch   1 Batch   19/269 - Train Accuracy: 0.5262, Validation Accuracy: 0.5229, Loss: 1.2594
# Epoch   1 Batch   20/269 - Train Accuracy: 0.4789, Validation Accuracy: 0.5190, Loss: 1.3785
# Epoch   1 Batch   21/269 - Train Accuracy: 0.4756, Validation Accuracy: 0.5158, Loss: 1.3995
# Epoch   1 Batch   22/269 - Train Accuracy: 0.5034, Validation Accuracy: 0.5224, Loss: 1.3095
# Epoch   1 Batch   23/269 - Train Accuracy: 0.5131, Validation Accuracy: 0.5287, Loss: 1.3233
# Epoch   1 Batch   24/269 - Train Accuracy: 0.4809, Validation Accuracy: 0.5271, Loss: 1.3605
# Epoch   1 Batch   25/269 - Train Accuracy: 0.4860, Validation Accuracy: 0.5313, Loss: 1.3689
# Epoch   1 Batch   26/269 - Train Accuracy: 0.5439, Validation Accuracy: 0.5350, Loss: 1.2283
# Epoch   1 Batch   27/269 - Train Accuracy: 0.4926, Validation Accuracy: 0.5241, Loss: 1.2995
# Epoch   1 Batch   28/269 - Train Accuracy: 0.4740, Validation Accuracy: 0.5348, Loss: 1.3787
# Epoch   1 Batch   29/269 - Train Accuracy: 0.4986, Validation Accuracy: 0.5371, Loss: 1.3369
# Epoch   1 Batch   30/269 - Train Accuracy: 0.5104, Validation Accuracy: 0.5352, Loss: 1.2829
# Epoch   1 Batch   31/269 - Train Accuracy: 0.5132, Validation Accuracy: 0.5320, Loss: 1.2766
# Epoch   1 Batch   32/269 - Train Accuracy: 0.5148, Validation Accuracy: 0.5412, Loss: 1.2895
# Epoch   1 Batch   33/269 - Train Accuracy: 0.5247, Validation Accuracy: 0.5364, Loss: 1.2554
# Epoch   1 Batch   34/269 - Train Accuracy: 0.5097, Validation Accuracy: 0.5258, Loss: 1.2784
# Epoch   1 Batch   35/269 - Train Accuracy: 0.5243, Validation Accuracy: 0.5362, Loss: 1.2810
# Epoch   1 Batch   36/269 - Train Accuracy: 0.5121, Validation Accuracy: 0.5283, Loss: 1.2832
# Epoch   1 Batch   37/269 - Train Accuracy: 0.5053, Validation Accuracy: 0.5188, Loss: 1.2807
# Epoch   1 Batch   38/269 - Train Accuracy: 0.5308, Validation Accuracy: 0.5440, Loss: 1.2805
# Epoch   1 Batch   39/269 - Train Accuracy: 0.5330, Validation Accuracy: 0.5466, Loss: 1.2640
# Epoch   1 Batch   40/269 - Train Accuracy: 0.4826, Validation Accuracy: 0.5289, Loss: 1.3126
# Epoch   1 Batch   41/269 - Train Accuracy: 0.5169, Validation Accuracy: 0.5447, Loss: 1.2719
# Epoch   1 Batch   42/269 - Train Accuracy: 0.5494, Validation Accuracy: 0.5419, Loss: 1.1952
# Epoch   1 Batch   43/269 - Train Accuracy: 0.4975, Validation Accuracy: 0.5305, Loss: 1.3035
# Epoch   1 Batch   44/269 - Train Accuracy: 0.5241, Validation Accuracy: 0.5341, Loss: 1.2540
# Epoch   1 Batch   45/269 - Train Accuracy: 0.5062, Validation Accuracy: 0.5436, Loss: 1.3020
# Epoch   1 Batch   46/269 - Train Accuracy: 0.5108, Validation Accuracy: 0.5459, Loss: 1.3014
# Epoch   1 Batch   47/269 - Train Accuracy: 0.5488, Validation Accuracy: 0.5515, Loss: 1.1742
# Epoch   1 Batch   48/269 - Train Accuracy: 0.5332, Validation Accuracy: 0.5509, Loss: 1.2145
# Epoch   1 Batch   49/269 - Train Accuracy: 0.5152, Validation Accuracy: 0.5498, Loss: 1.2794
# Epoch   1 Batch   50/269 - Train Accuracy: 0.5042, Validation Accuracy: 0.5443, Loss: 1.2806
# Epoch   1 Batch   51/269 - Train Accuracy: 0.5188, Validation Accuracy: 0.5462, Loss: 1.2592
# Epoch   1 Batch   52/269 - Train Accuracy: 0.5231, Validation Accuracy: 0.5422, Loss: 1.2030
# Epoch   1 Batch   53/269 - Train Accuracy: 0.5028, Validation Accuracy: 0.5401, Loss: 1.2882
# Epoch   1 Batch   54/269 - Train Accuracy: 0.5007, Validation Accuracy: 0.5407, Loss: 1.2712
# Epoch   1 Batch   55/269 - Train Accuracy: 0.5374, Validation Accuracy: 0.5509, Loss: 1.2099
# Epoch   1 Batch   56/269 - Train Accuracy: 0.5433, Validation Accuracy: 0.5556, Loss: 1.2218
# Epoch   1 Batch   57/269 - Train Accuracy: 0.5423, Validation Accuracy: 0.5597, Loss: 1.2240
# Epoch   1 Batch   58/269 - Train Accuracy: 0.5341, Validation Accuracy: 0.5514, Loss: 1.2101
# Epoch   1 Batch   59/269 - Train Accuracy: 0.5420, Validation Accuracy: 0.5499, Loss: 1.1916
# Epoch   1 Batch   60/269 - Train Accuracy: 0.5431, Validation Accuracy: 0.5478, Loss: 1.1605
# Epoch   1 Batch   61/269 - Train Accuracy: 0.5550, Validation Accuracy: 0.5496, Loss: 1.1377
# Epoch   1 Batch   62/269 - Train Accuracy: 0.5475, Validation Accuracy: 0.5517, Loss: 1.1701
# Epoch   1 Batch   63/269 - Train Accuracy: 0.5245, Validation Accuracy: 0.5558, Loss: 1.2081
# Epoch   1 Batch   64/269 - Train Accuracy: 0.5346, Validation Accuracy: 0.5589, Loss: 1.1902
# Epoch   1 Batch   65/269 - Train Accuracy: 0.5323, Validation Accuracy: 0.5534, Loss: 1.1743
# Epoch   1 Batch   66/269 - Train Accuracy: 0.5507, Validation Accuracy: 0.5530, Loss: 1.1462
# Epoch   1 Batch   67/269 - Train Accuracy: 0.5264, Validation Accuracy: 0.5526, Loss: 1.1990
# Epoch   1 Batch   68/269 - Train Accuracy: 0.5326, Validation Accuracy: 0.5574, Loss: 1.1990
# Epoch   1 Batch   69/269 - Train Accuracy: 0.5158, Validation Accuracy: 0.5575, Loss: 1.2750
# Epoch   1 Batch   70/269 - Train Accuracy: 0.5459, Validation Accuracy: 0.5593, Loss: 1.1740
# Epoch   1 Batch   71/269 - Train Accuracy: 0.5197, Validation Accuracy: 0.5589, Loss: 1.2289
# Epoch   1 Batch   72/269 - Train Accuracy: 0.5535, Validation Accuracy: 0.5587, Loss: 1.1362
# Epoch   1 Batch   73/269 - Train Accuracy: 0.5423, Validation Accuracy: 0.5622, Loss: 1.1926
# Epoch   1 Batch   74/269 - Train Accuracy: 0.5398, Validation Accuracy: 0.5595, Loss: 1.1930
# Epoch   1 Batch   75/269 - Train Accuracy: 0.5401, Validation Accuracy: 0.5627, Loss: 1.1620
# Epoch   1 Batch   76/269 - Train Accuracy: 0.5342, Validation Accuracy: 0.5636, Loss: 1.1762
# Epoch   1 Batch   77/269 - Train Accuracy: 0.5569, Validation Accuracy: 0.5641, Loss: 1.1545
# Epoch   1 Batch   78/269 - Train Accuracy: 0.5343, Validation Accuracy: 0.5597, Loss: 1.1637
# Epoch   1 Batch   79/269 - Train Accuracy: 0.5467, Validation Accuracy: 0.5598, Loss: 1.1410
# Epoch   1 Batch   80/269 - Train Accuracy: 0.5517, Validation Accuracy: 0.5583, Loss: 1.1424
# Epoch   1 Batch   81/269 - Train Accuracy: 0.5312, Validation Accuracy: 0.5604, Loss: 1.1660
# Epoch   1 Batch   82/269 - Train Accuracy: 0.5528, Validation Accuracy: 0.5597, Loss: 1.1077
# Epoch   1 Batch   83/269 - Train Accuracy: 0.5572, Validation Accuracy: 0.5644, Loss: 1.1303
# Epoch   1 Batch   84/269 - Train Accuracy: 0.5466, Validation Accuracy: 0.5650, Loss: 1.1199
# Epoch   1 Batch   85/269 - Train Accuracy: 0.5433, Validation Accuracy: 0.5671, Loss: 1.1388
# Epoch   1 Batch   86/269 - Train Accuracy: 0.5245, Validation Accuracy: 0.5643, Loss: 1.1498
# Epoch   1 Batch   87/269 - Train Accuracy: 0.5047, Validation Accuracy: 0.5624, Loss: 1.2103
# Epoch   1 Batch   88/269 - Train Accuracy: 0.5441, Validation Accuracy: 0.5634, Loss: 1.1225
# Epoch   1 Batch   89/269 - Train Accuracy: 0.5572, Validation Accuracy: 0.5660, Loss: 1.1178
# Epoch   1 Batch   90/269 - Train Accuracy: 0.5049, Validation Accuracy: 0.5613, Loss: 1.1908
# Epoch   1 Batch   91/269 - Train Accuracy: 0.5405, Validation Accuracy: 0.5629, Loss: 1.1086
# Epoch   1 Batch   92/269 - Train Accuracy: 0.5378, Validation Accuracy: 0.5609, Loss: 1.1142
# Epoch   1 Batch   93/269 - Train Accuracy: 0.5634, Validation Accuracy: 0.5644, Loss: 1.0717
# Epoch   1 Batch   94/269 - Train Accuracy: 0.5456, Validation Accuracy: 0.5621, Loss: 1.1308
# Epoch   1 Batch   95/269 - Train Accuracy: 0.5520, Validation Accuracy: 0.5616, Loss: 1.1185
# Epoch   1 Batch   96/269 - Train Accuracy: 0.5616, Validation Accuracy: 0.5629, Loss: 1.0965
# Epoch   1 Batch   97/269 - Train Accuracy: 0.5351, Validation Accuracy: 0.5591, Loss: 1.1180
# Epoch   1 Batch   98/269 - Train Accuracy: 0.5652, Validation Accuracy: 0.5588, Loss: 1.0852
# Epoch   1 Batch   99/269 - Train Accuracy: 0.5329, Validation Accuracy: 0.5641, Loss: 1.1549
# Epoch   1 Batch  100/269 - Train Accuracy: 0.5585, Validation Accuracy: 0.5599, Loss: 1.0726
# Epoch   1 Batch  101/269 - Train Accuracy: 0.5176, Validation Accuracy: 0.5570, Loss: 1.1450
# Epoch   1 Batch  102/269 - Train Accuracy: 0.5363, Validation Accuracy: 0.5550, Loss: 1.0821
# Epoch   1 Batch  103/269 - Train Accuracy: 0.5346, Validation Accuracy: 0.5575, Loss: 1.0815
# Epoch   1 Batch  104/269 - Train Accuracy: 0.5401, Validation Accuracy: 0.5577, Loss: 1.0852
# Epoch   1 Batch  105/269 - Train Accuracy: 0.5379, Validation Accuracy: 0.5559, Loss: 1.1026
# Epoch   1 Batch  106/269 - Train Accuracy: 0.5451, Validation Accuracy: 0.5588, Loss: 1.0782
# Epoch   1 Batch  107/269 - Train Accuracy: 0.5140, Validation Accuracy: 0.5594, Loss: 1.1304
# Epoch   1 Batch  108/269 - Train Accuracy: 0.5459, Validation Accuracy: 0.5583, Loss: 1.0627
# Epoch   1 Batch  109/269 - Train Accuracy: 0.5289, Validation Accuracy: 0.5602, Loss: 1.0961
# Epoch   1 Batch  110/269 - Train Accuracy: 0.5458, Validation Accuracy: 0.5596, Loss: 1.0623
# Epoch   1 Batch  111/269 - Train Accuracy: 0.5188, Validation Accuracy: 0.5623, Loss: 1.1436
# Epoch   1 Batch  112/269 - Train Accuracy: 0.5524, Validation Accuracy: 0.5581, Loss: 1.0675
# Epoch   1 Batch  113/269 - Train Accuracy: 0.5545, Validation Accuracy: 0.5538, Loss: 1.0255
# Epoch   1 Batch  114/269 - Train Accuracy: 0.5277, Validation Accuracy: 0.5475, Loss: 1.0609
# Epoch   1 Batch  115/269 - Train Accuracy: 0.5272, Validation Accuracy: 0.5558, Loss: 1.0917
# Epoch   1 Batch  116/269 - Train Accuracy: 0.5550, Validation Accuracy: 0.5566, Loss: 1.0642
# Epoch   1 Batch  117/269 - Train Accuracy: 0.5346, Validation Accuracy: 0.5544, Loss: 1.0506
# Epoch   1 Batch  118/269 - Train Accuracy: 0.5632, Validation Accuracy: 0.5599, Loss: 1.0259
# Epoch   1 Batch  119/269 - Train Accuracy: 0.5353, Validation Accuracy: 0.5558, Loss: 1.1154
# Epoch   1 Batch  120/269 - Train Accuracy: 0.5244, Validation Accuracy: 0.5623, Loss: 1.0888
# Epoch   1 Batch  121/269 - Train Accuracy: 0.5395, Validation Accuracy: 0.5622, Loss: 1.0306
# Epoch   1 Batch  122/269 - Train Accuracy: 0.5514, Validation Accuracy: 0.5629, Loss: 1.0343
# Epoch   1 Batch  123/269 - Train Accuracy: 0.5300, Validation Accuracy: 0.5642, Loss: 1.0891
# Epoch   1 Batch  124/269 - Train Accuracy: 0.5501, Validation Accuracy: 0.5659, Loss: 1.0086
# Epoch   1 Batch  125/269 - Train Accuracy: 0.5486, Validation Accuracy: 0.5670, Loss: 1.0153
# Epoch   1 Batch  126/269 - Train Accuracy: 0.5577, Validation Accuracy: 0.5597, Loss: 1.0109
# Epoch   1 Batch  127/269 - Train Accuracy: 0.5265, Validation Accuracy: 0.5610, Loss: 1.0808
# Epoch   1 Batch  128/269 - Train Accuracy: 0.5684, Validation Accuracy: 0.5602, Loss: 1.0228
# Epoch   1 Batch  129/269 - Train Accuracy: 0.5407, Validation Accuracy: 0.5639, Loss: 1.0443
# Epoch   1 Batch  130/269 - Train Accuracy: 0.5241, Validation Accuracy: 0.5672, Loss: 1.0795
# Epoch   1 Batch  131/269 - Train Accuracy: 0.5423, Validation Accuracy: 0.5696, Loss: 1.0649
# Epoch   1 Batch  132/269 - Train Accuracy: 0.5490, Validation Accuracy: 0.5665, Loss: 1.0208
# Epoch   1 Batch  133/269 - Train Accuracy: 0.5437, Validation Accuracy: 0.5620, Loss: 0.9942
# Epoch   1 Batch  134/269 - Train Accuracy: 0.5100, Validation Accuracy: 0.5597, Loss: 1.0571
# Epoch   1 Batch  135/269 - Train Accuracy: 0.5136, Validation Accuracy: 0.5518, Loss: 1.0890
# Epoch   1 Batch  136/269 - Train Accuracy: 0.5103, Validation Accuracy: 0.5534, Loss: 1.0726
# Epoch   1 Batch  137/269 - Train Accuracy: 0.5366, Validation Accuracy: 0.5559, Loss: 1.0507
# Epoch   1 Batch  138/269 - Train Accuracy: 0.5393, Validation Accuracy: 0.5614, Loss: 1.0318
# Epoch   1 Batch  139/269 - Train Accuracy: 0.5636, Validation Accuracy: 0.5570, Loss: 0.9803
# Epoch   1 Batch  140/269 - Train Accuracy: 0.5558, Validation Accuracy: 0.5604, Loss: 1.0144
# Epoch   1 Batch  141/269 - Train Accuracy: 0.5496, Validation Accuracy: 0.5626, Loss: 1.0169
# Epoch   1 Batch  142/269 - Train Accuracy: 0.5656, Validation Accuracy: 0.5660, Loss: 0.9845
# Epoch   1 Batch  143/269 - Train Accuracy: 0.5600, Validation Accuracy: 0.5660, Loss: 0.9903
# Epoch   1 Batch  144/269 - Train Accuracy: 0.5460, Validation Accuracy: 0.5596, Loss: 0.9645
# Epoch   1 Batch  145/269 - Train Accuracy: 0.5524, Validation Accuracy: 0.5627, Loss: 0.9911
# Epoch   1 Batch  146/269 - Train Accuracy: 0.5525, Validation Accuracy: 0.5613, Loss: 0.9749
# Epoch   1 Batch  147/269 - Train Accuracy: 0.5713, Validation Accuracy: 0.5577, Loss: 0.9437
# Epoch   1 Batch  148/269 - Train Accuracy: 0.5351, Validation Accuracy: 0.5561, Loss: 1.0069
# Epoch   1 Batch  149/269 - Train Accuracy: 0.5559, Validation Accuracy: 0.5569, Loss: 0.9931
# Epoch   1 Batch  150/269 - Train Accuracy: 0.5480, Validation Accuracy: 0.5587, Loss: 0.9918
# Epoch   1 Batch  151/269 - Train Accuracy: 0.5885, Validation Accuracy: 0.5616, Loss: 0.9490
# Epoch   1 Batch  152/269 - Train Accuracy: 0.5587, Validation Accuracy: 0.5628, Loss: 0.9835
# Epoch   1 Batch  153/269 - Train Accuracy: 0.5605, Validation Accuracy: 0.5659, Loss: 0.9619
# Epoch   1 Batch  154/269 - Train Accuracy: 0.5377, Validation Accuracy: 0.5667, Loss: 1.0058
# Epoch   1 Batch  155/269 - Train Accuracy: 0.5897, Validation Accuracy: 0.5668, Loss: 0.9204
# Epoch   1 Batch  156/269 - Train Accuracy: 0.5473, Validation Accuracy: 0.5683, Loss: 1.0181
# Epoch   1 Batch  157/269 - Train Accuracy: 0.5641, Validation Accuracy: 0.5673, Loss: 0.9743
# Epoch   1 Batch  158/269 - Train Accuracy: 0.5639, Validation Accuracy: 0.5690, Loss: 0.9605
# Epoch   1 Batch  159/269 - Train Accuracy: 0.5585, Validation Accuracy: 0.5646, Loss: 0.9666
# Epoch   1 Batch  160/269 - Train Accuracy: 0.5593, Validation Accuracy: 0.5643, Loss: 0.9680
# Epoch   1 Batch  161/269 - Train Accuracy: 0.5538, Validation Accuracy: 0.5671, Loss: 0.9736
# Epoch   1 Batch  162/269 - Train Accuracy: 0.5547, Validation Accuracy: 0.5676, Loss: 0.9486
# Epoch   1 Batch  163/269 - Train Accuracy: 0.5746, Validation Accuracy: 0.5646, Loss: 0.9428
# Epoch   1 Batch  164/269 - Train Accuracy: 0.5694, Validation Accuracy: 0.5621, Loss: 0.9504
# Epoch   1 Batch  165/269 - Train Accuracy: 0.5409, Validation Accuracy: 0.5659, Loss: 0.9835
# Epoch   1 Batch  166/269 - Train Accuracy: 0.5913, Validation Accuracy: 0.5700, Loss: 0.9043
# Epoch   1 Batch  167/269 - Train Accuracy: 0.5660, Validation Accuracy: 0.5684, Loss: 0.9461
# Epoch   1 Batch  168/269 - Train Accuracy: 0.5547, Validation Accuracy: 0.5699, Loss: 0.9673
# Epoch   1 Batch  169/269 - Train Accuracy: 0.5602, Validation Accuracy: 0.5700, Loss: 0.9521
# Epoch   1 Batch  170/269 - Train Accuracy: 0.5711, Validation Accuracy: 0.5737, Loss: 0.9365
# Epoch   1 Batch  171/269 - Train Accuracy: 0.5491, Validation Accuracy: 0.5731, Loss: 0.9860
# Epoch   1 Batch  172/269 - Train Accuracy: 0.5599, Validation Accuracy: 0.5730, Loss: 0.9546
# Epoch   1 Batch  173/269 - Train Accuracy: 0.5643, Validation Accuracy: 0.5680, Loss: 0.9309
# Epoch   1 Batch  174/269 - Train Accuracy: 0.5586, Validation Accuracy: 0.5692, Loss: 0.9433
# Epoch   1 Batch  175/269 - Train Accuracy: 0.5680, Validation Accuracy: 0.5714, Loss: 0.9463
# Epoch   1 Batch  176/269 - Train Accuracy: 0.5581, Validation Accuracy: 0.5737, Loss: 0.9892
# Epoch   1 Batch  177/269 - Train Accuracy: 0.5710, Validation Accuracy: 0.5684, Loss: 0.9074
# Epoch   1 Batch  178/269 - Train Accuracy: 0.5538, Validation Accuracy: 0.5629, Loss: 0.9554
# Epoch   1 Batch  179/269 - Train Accuracy: 0.5674, Validation Accuracy: 0.5661, Loss: 0.9371
# Epoch   1 Batch  180/269 - Train Accuracy: 0.5685, Validation Accuracy: 0.5691, Loss: 0.9140
# Epoch   1 Batch  181/269 - Train Accuracy: 0.5517, Validation Accuracy: 0.5686, Loss: 0.9295
# Epoch   1 Batch  182/269 - Train Accuracy: 0.5727, Validation Accuracy: 0.5725, Loss: 0.9415
# Epoch   1 Batch  183/269 - Train Accuracy: 0.6317, Validation Accuracy: 0.5659, Loss: 0.8008
# Epoch   1 Batch  184/269 - Train Accuracy: 0.5509, Validation Accuracy: 0.5654, Loss: 0.9672
# Epoch   1 Batch  185/269 - Train Accuracy: 0.5685, Validation Accuracy: 0.5732, Loss: 0.9220
# Epoch   1 Batch  186/269 - Train Accuracy: 0.5461, Validation Accuracy: 0.5749, Loss: 0.9507
# Epoch   1 Batch  187/269 - Train Accuracy: 0.5671, Validation Accuracy: 0.5749, Loss: 0.9103
# Epoch   1 Batch  188/269 - Train Accuracy: 0.5784, Validation Accuracy: 0.5721, Loss: 0.8973
# Epoch   1 Batch  189/269 - Train Accuracy: 0.5762, Validation Accuracy: 0.5692, Loss: 0.8962
# Epoch   1 Batch  190/269 - Train Accuracy: 0.5550, Validation Accuracy: 0.5724, Loss: 0.9020
# Epoch   1 Batch  191/269 - Train Accuracy: 0.5721, Validation Accuracy: 0.5726, Loss: 0.9094
# Epoch   1 Batch  192/269 - Train Accuracy: 0.5746, Validation Accuracy: 0.5765, Loss: 0.9220
# Epoch   1 Batch  193/269 - Train Accuracy: 0.5705, Validation Accuracy: 0.5724, Loss: 0.9092
# Epoch   1 Batch  194/269 - Train Accuracy: 0.5839, Validation Accuracy: 0.5706, Loss: 0.9238
# Epoch   1 Batch  195/269 - Train Accuracy: 0.5600, Validation Accuracy: 0.5716, Loss: 0.9179
# Epoch   1 Batch  196/269 - Train Accuracy: 0.5487, Validation Accuracy: 0.5743, Loss: 0.9078
# Epoch   1 Batch  197/269 - Train Accuracy: 0.5519, Validation Accuracy: 0.5779, Loss: 0.9376
# Epoch   1 Batch  198/269 - Train Accuracy: 0.5563, Validation Accuracy: 0.5788, Loss: 0.9600
# Epoch   1 Batch  199/269 - Train Accuracy: 0.5648, Validation Accuracy: 0.5749, Loss: 0.9260
# Epoch   1 Batch  200/269 - Train Accuracy: 0.5550, Validation Accuracy: 0.5761, Loss: 0.9263
# Epoch   1 Batch  201/269 - Train Accuracy: 0.5681, Validation Accuracy: 0.5771, Loss: 0.9013
# Epoch   1 Batch  202/269 - Train Accuracy: 0.5657, Validation Accuracy: 0.5692, Loss: 0.9000
# Epoch   1 Batch  203/269 - Train Accuracy: 0.5375, Validation Accuracy: 0.5657, Loss: 0.9504
# Epoch   1 Batch  204/269 - Train Accuracy: 0.5394, Validation Accuracy: 0.5623, Loss: 0.9302
# Epoch   1 Batch  205/269 - Train Accuracy: 0.5527, Validation Accuracy: 0.5625, Loss: 0.8893
# Epoch   1 Batch  206/269 - Train Accuracy: 0.5385, Validation Accuracy: 0.5730, Loss: 0.9413
# Epoch   1 Batch  207/269 - Train Accuracy: 0.5934, Validation Accuracy: 0.5712, Loss: 0.8576
# Epoch   1 Batch  208/269 - Train Accuracy: 0.5375, Validation Accuracy: 0.5715, Loss: 0.9448
# Epoch   1 Batch  209/269 - Train Accuracy: 0.5502, Validation Accuracy: 0.5724, Loss: 0.9122
# Epoch   1 Batch  210/269 - Train Accuracy: 0.5737, Validation Accuracy: 0.5714, Loss: 0.8844
# Epoch   1 Batch  211/269 - Train Accuracy: 0.5709, Validation Accuracy: 0.5724, Loss: 0.9043
# Epoch   1 Batch  212/269 - Train Accuracy: 0.5824, Validation Accuracy: 0.5715, Loss: 0.8740
# Epoch   1 Batch  213/269 - Train Accuracy: 0.5741, Validation Accuracy: 0.5717, Loss: 0.8735
# Epoch   1 Batch  214/269 - Train Accuracy: 0.5677, Validation Accuracy: 0.5721, Loss: 0.8823
# Epoch   1 Batch  215/269 - Train Accuracy: 0.5931, Validation Accuracy: 0.5686, Loss: 0.8307
# Epoch   1 Batch  216/269 - Train Accuracy: 0.5391, Validation Accuracy: 0.5716, Loss: 0.9449
# Epoch   1 Batch  217/269 - Train Accuracy: 0.5478, Validation Accuracy: 0.5766, Loss: 0.9183
# Epoch   1 Batch  218/269 - Train Accuracy: 0.5700, Validation Accuracy: 0.5756, Loss: 0.9176
# Epoch   1 Batch  219/269 - Train Accuracy: 0.5655, Validation Accuracy: 0.5784, Loss: 0.9147
# Epoch   1 Batch  220/269 - Train Accuracy: 0.5789, Validation Accuracy: 0.5746, Loss: 0.8338
# Epoch   1 Batch  221/269 - Train Accuracy: 0.5890, Validation Accuracy: 0.5812, Loss: 0.8677
# Epoch   1 Batch  222/269 - Train Accuracy: 0.5762, Validation Accuracy: 0.5821, Loss: 0.8426
# Epoch   1 Batch  223/269 - Train Accuracy: 0.5714, Validation Accuracy: 0.5795, Loss: 0.8487
# Epoch   1 Batch  224/269 - Train Accuracy: 0.5831, Validation Accuracy: 0.5754, Loss: 0.8885
# Epoch   1 Batch  225/269 - Train Accuracy: 0.5636, Validation Accuracy: 0.5754, Loss: 0.8887
# Epoch   1 Batch  226/269 - Train Accuracy: 0.5655, Validation Accuracy: 0.5774, Loss: 0.8699
# Epoch   1 Batch  227/269 - Train Accuracy: 0.6260, Validation Accuracy: 0.5821, Loss: 0.7618
# Epoch   1 Batch  228/269 - Train Accuracy: 0.5684, Validation Accuracy: 0.5768, Loss: 0.8713
# Epoch   1 Batch  229/269 - Train Accuracy: 0.5757, Validation Accuracy: 0.5630, Loss: 0.8627
# Epoch   1 Batch  230/269 - Train Accuracy: 0.5688, Validation Accuracy: 0.5653, Loss: 0.8646
# Epoch   1 Batch  231/269 - Train Accuracy: 0.5483, Validation Accuracy: 0.5672, Loss: 0.9164
# Epoch   1 Batch  232/269 - Train Accuracy: 0.5372, Validation Accuracy: 0.5816, Loss: 0.8967
# Epoch   1 Batch  233/269 - Train Accuracy: 0.5890, Validation Accuracy: 0.5812, Loss: 0.8659
# Epoch   1 Batch  234/269 - Train Accuracy: 0.5822, Validation Accuracy: 0.5810, Loss: 0.8670
# Epoch   1 Batch  235/269 - Train Accuracy: 0.5842, Validation Accuracy: 0.5770, Loss: 0.8578
# Epoch   1 Batch  236/269 - Train Accuracy: 0.5695, Validation Accuracy: 0.5771, Loss: 0.8523
# Epoch   1 Batch  237/269 - Train Accuracy: 0.5698, Validation Accuracy: 0.5860, Loss: 0.8570
# Epoch   1 Batch  238/269 - Train Accuracy: 0.5979, Validation Accuracy: 0.5882, Loss: 0.8493
# Epoch   1 Batch  239/269 - Train Accuracy: 0.5984, Validation Accuracy: 0.5852, Loss: 0.8486
# Epoch   1 Batch  240/269 - Train Accuracy: 0.6095, Validation Accuracy: 0.5840, Loss: 0.7890
# Epoch   1 Batch  241/269 - Train Accuracy: 0.5873, Validation Accuracy: 0.5841, Loss: 0.8597
# Epoch   1 Batch  242/269 - Train Accuracy: 0.5747, Validation Accuracy: 0.5822, Loss: 0.8541
# Epoch   1 Batch  243/269 - Train Accuracy: 0.6013, Validation Accuracy: 0.5859, Loss: 0.8252
# Epoch   1 Batch  244/269 - Train Accuracy: 0.5772, Validation Accuracy: 0.5836, Loss: 0.8484
# Epoch   1 Batch  245/269 - Train Accuracy: 0.5604, Validation Accuracy: 0.5717, Loss: 0.8970
# Epoch   1 Batch  246/269 - Train Accuracy: 0.5568, Validation Accuracy: 0.5717, Loss: 0.8656
# Epoch   1 Batch  247/269 - Train Accuracy: 0.5730, Validation Accuracy: 0.5865, Loss: 0.8846
# Epoch   1 Batch  248/269 - Train Accuracy: 0.5752, Validation Accuracy: 0.5898, Loss: 0.8405
# Epoch   1 Batch  249/269 - Train Accuracy: 0.6051, Validation Accuracy: 0.5875, Loss: 0.8118
# ...
# Epoch   9 Batch   97/269 - Train Accuracy: 0.8944, Validation Accuracy: 0.8930, Loss: 0.1482
# Epoch   9 Batch   98/269 - Train Accuracy: 0.8869, Validation Accuracy: 0.9007, Loss: 0.1484
# Epoch   9 Batch   99/269 - Train Accuracy: 0.8806, Validation Accuracy: 0.8978, Loss: 0.1445
# Epoch   9 Batch  100/269 - Train Accuracy: 0.9087, Validation Accuracy: 0.8936, Loss: 0.1391
# Epoch   9 Batch  101/269 - Train Accuracy: 0.8782, Validation Accuracy: 0.8965, Loss: 0.1632
# Epoch   9 Batch  102/269 - Train Accuracy: 0.8982, Validation Accuracy: 0.8945, Loss: 0.1442
# Epoch   9 Batch  103/269 - Train Accuracy: 0.9038, Validation Accuracy: 0.8999, Loss: 0.1558
# Epoch   9 Batch  104/269 - Train Accuracy: 0.8935, Validation Accuracy: 0.9017, Loss: 0.1395
# Epoch   9 Batch  105/269 - Train Accuracy: 0.8823, Validation Accuracy: 0.9035, Loss: 0.1499
# Epoch   9 Batch  106/269 - Train Accuracy: 0.8943, Validation Accuracy: 0.9028, Loss: 0.1328
# Epoch   9 Batch  107/269 - Train Accuracy: 0.9019, Validation Accuracy: 0.9082, Loss: 0.1522
# Epoch   9 Batch  108/269 - Train Accuracy: 0.9009, Validation Accuracy: 0.9058, Loss: 0.1499
# Epoch   9 Batch  109/269 - Train Accuracy: 0.8613, Validation Accuracy: 0.9020, Loss: 0.1584
# Epoch   9 Batch  110/269 - Train Accuracy: 0.8983, Validation Accuracy: 0.9029, Loss: 0.1383
# Epoch   9 Batch  111/269 - Train Accuracy: 0.8872, Validation Accuracy: 0.8977, Loss: 0.1582
# Epoch   9 Batch  112/269 - Train Accuracy: 0.8948, Validation Accuracy: 0.9006, Loss: 0.1461
# Epoch   9 Batch  113/269 - Train Accuracy: 0.8824, Validation Accuracy: 0.8994, Loss: 0.1490
# Epoch   9 Batch  114/269 - Train Accuracy: 0.8955, Validation Accuracy: 0.8990, Loss: 0.1439
# Epoch   9 Batch  115/269 - Train Accuracy: 0.8835, Validation Accuracy: 0.9007, Loss: 0.1461
# Epoch   9 Batch  116/269 - Train Accuracy: 0.9082, Validation Accuracy: 0.8993, Loss: 0.1513
# Epoch   9 Batch  117/269 - Train Accuracy: 0.8916, Validation Accuracy: 0.8948, Loss: 0.1415
# Epoch   9 Batch  118/269 - Train Accuracy: 0.9112, Validation Accuracy: 0.8974, Loss: 0.1307
# Epoch   9 Batch  119/269 - Train Accuracy: 0.8963, Validation Accuracy: 0.9003, Loss: 0.1557
# Epoch   9 Batch  120/269 - Train Accuracy: 0.8869, Validation Accuracy: 0.8920, Loss: 0.1471
# Epoch   9 Batch  121/269 - Train Accuracy: 0.8927, Validation Accuracy: 0.8968, Loss: 0.1425
# Epoch   9 Batch  122/269 - Train Accuracy: 0.8996, Validation Accuracy: 0.9000, Loss: 0.1426
# Epoch   9 Batch  123/269 - Train Accuracy: 0.8858, Validation Accuracy: 0.9013, Loss: 0.1450
# Epoch   9 Batch  124/269 - Train Accuracy: 0.8893, Validation Accuracy: 0.8996, Loss: 0.1336
# Epoch   9 Batch  125/269 - Train Accuracy: 0.8994, Validation Accuracy: 0.9002, Loss: 0.1330
# Epoch   9 Batch  126/269 - Train Accuracy: 0.8755, Validation Accuracy: 0.9056, Loss: 0.1384
# Epoch   9 Batch  127/269 - Train Accuracy: 0.8831, Validation Accuracy: 0.9047, Loss: 0.1458
# Epoch   9 Batch  128/269 - Train Accuracy: 0.9012, Validation Accuracy: 0.9070, Loss: 0.1479
# Epoch   9 Batch  129/269 - Train Accuracy: 0.8836, Validation Accuracy: 0.9073, Loss: 0.1466
# Epoch   9 Batch  130/269 - Train Accuracy: 0.8915, Validation Accuracy: 0.9041, Loss: 0.1515
# Epoch   9 Batch  131/269 - Train Accuracy: 0.8831, Validation Accuracy: 0.9090, Loss: 0.1441
# Epoch   9 Batch  132/269 - Train Accuracy: 0.8818, Validation Accuracy: 0.8996, Loss: 0.1507
# Epoch   9 Batch  133/269 - Train Accuracy: 0.8958, Validation Accuracy: 0.9006, Loss: 0.1298
# Epoch   9 Batch  134/269 - Train Accuracy: 0.8766, Validation Accuracy: 0.8998, Loss: 0.1508
# Epoch   9 Batch  135/269 - Train Accuracy: 0.8949, Validation Accuracy: 0.8956, Loss: 0.1523
# Epoch   9 Batch  136/269 - Train Accuracy: 0.8715, Validation Accuracy: 0.9087, Loss: 0.1515
# Epoch   9 Batch  137/269 - Train Accuracy: 0.8980, Validation Accuracy: 0.9087, Loss: 0.1565
# Epoch   9 Batch  138/269 - Train Accuracy: 0.8866, Validation Accuracy: 0.9053, Loss: 0.1402
# Epoch   9 Batch  139/269 - Train Accuracy: 0.8917, Validation Accuracy: 0.8986, Loss: 0.1357
# Epoch   9 Batch  140/269 - Train Accuracy: 0.8911, Validation Accuracy: 0.8975, Loss: 0.1488
# Epoch   9 Batch  141/269 - Train Accuracy: 0.8956, Validation Accuracy: 0.9002, Loss: 0.1568
# Epoch   9 Batch  142/269 - Train Accuracy: 0.8871, Validation Accuracy: 0.8994, Loss: 0.1348
# Epoch   9 Batch  143/269 - Train Accuracy: 0.9026, Validation Accuracy: 0.9010, Loss: 0.1353
# Epoch   9 Batch  144/269 - Train Accuracy: 0.9031, Validation Accuracy: 0.9012, Loss: 0.1271
# Epoch   9 Batch  145/269 - Train Accuracy: 0.8946, Validation Accuracy: 0.9046, Loss: 0.1345
# Epoch   9 Batch  146/269 - Train Accuracy: 0.8948, Validation Accuracy: 0.9066, Loss: 0.1414
# Epoch   9 Batch  147/269 - Train Accuracy: 0.8978, Validation Accuracy: 0.9020, Loss: 0.1482
# Epoch   9 Batch  148/269 - Train Accuracy: 0.9008, Validation Accuracy: 0.9004, Loss: 0.1379
# Epoch   9 Batch  149/269 - Train Accuracy: 0.8831, Validation Accuracy: 0.8999, Loss: 0.1508
# Epoch   9 Batch  150/269 - Train Accuracy: 0.8825, Validation Accuracy: 0.9023, Loss: 0.1417
# Epoch   9 Batch  151/269 - Train Accuracy: 0.8896, Validation Accuracy: 0.9003, Loss: 0.1435
# Epoch   9 Batch  152/269 - Train Accuracy: 0.8884, Validation Accuracy: 0.9031, Loss: 0.1438
# Epoch   9 Batch  153/269 - Train Accuracy: 0.9042, Validation Accuracy: 0.8962, Loss: 0.1391
# Epoch   9 Batch  154/269 - Train Accuracy: 0.9045, Validation Accuracy: 0.9023, Loss: 0.1398
# Epoch   9 Batch  155/269 - Train Accuracy: 0.8963, Validation Accuracy: 0.9022, Loss: 0.1403
# Epoch   9 Batch  156/269 - Train Accuracy: 0.8911, Validation Accuracy: 0.9006, Loss: 0.1455
# Epoch   9 Batch  157/269 - Train Accuracy: 0.8730, Validation Accuracy: 0.8903, Loss: 0.1389
# Epoch   9 Batch  158/269 - Train Accuracy: 0.8919, Validation Accuracy: 0.9060, Loss: 0.1511
# Epoch   9 Batch  159/269 - Train Accuracy: 0.8787, Validation Accuracy: 0.8999, Loss: 0.1472
# Epoch   9 Batch  160/269 - Train Accuracy: 0.8844, Validation Accuracy: 0.9054, Loss: 0.1498
# Epoch   9 Batch  161/269 - Train Accuracy: 0.8919, Validation Accuracy: 0.9015, Loss: 0.1494
# Epoch   9 Batch  162/269 - Train Accuracy: 0.9037, Validation Accuracy: 0.9086, Loss: 0.1391
# Epoch   9 Batch  163/269 - Train Accuracy: 0.8951, Validation Accuracy: 0.9078, Loss: 0.1393
# Epoch   9 Batch  164/269 - Train Accuracy: 0.9011, Validation Accuracy: 0.9020, Loss: 0.1459
# Epoch   9 Batch  165/269 - Train Accuracy: 0.9014, Validation Accuracy: 0.9007, Loss: 0.1373
# Epoch   9 Batch  166/269 - Train Accuracy: 0.9003, Validation Accuracy: 0.9011, Loss: 0.1472
# Epoch   9 Batch  167/269 - Train Accuracy: 0.8989, Validation Accuracy: 0.9058, Loss: 0.1420
# Epoch   9 Batch  168/269 - Train Accuracy: 0.8944, Validation Accuracy: 0.9042, Loss: 0.1459
# Epoch   9 Batch  169/269 - Train Accuracy: 0.8757, Validation Accuracy: 0.9014, Loss: 0.1444
# Epoch   9 Batch  170/269 - Train Accuracy: 0.8825, Validation Accuracy: 0.9055, Loss: 0.1462
# Epoch   9 Batch  171/269 - Train Accuracy: 0.9138, Validation Accuracy: 0.9126, Loss: 0.1438
# Epoch   9 Batch  172/269 - Train Accuracy: 0.8814, Validation Accuracy: 0.9059, Loss: 0.1536
# Epoch   9 Batch  173/269 - Train Accuracy: 0.8989, Validation Accuracy: 0.9066, Loss: 0.1332
# Epoch   9 Batch  174/269 - Train Accuracy: 0.9034, Validation Accuracy: 0.9084, Loss: 0.1399
# Epoch   9 Batch  175/269 - Train Accuracy: 0.8820, Validation Accuracy: 0.9031, Loss: 0.1539
# Epoch   9 Batch  176/269 - Train Accuracy: 0.8872, Validation Accuracy: 0.8967, Loss: 0.1514
# Epoch   9 Batch  177/269 - Train Accuracy: 0.8933, Validation Accuracy: 0.8994, Loss: 0.1384
# Epoch   9 Batch  178/269 - Train Accuracy: 0.8896, Validation Accuracy: 0.9010, Loss: 0.1331
# Epoch   9 Batch  179/269 - Train Accuracy: 0.8827, Validation Accuracy: 0.9031, Loss: 0.1404
# Epoch   9 Batch  180/269 - Train Accuracy: 0.8994, Validation Accuracy: 0.9003, Loss: 0.1337
# Epoch   9 Batch  181/269 - Train Accuracy: 0.8884, Validation Accuracy: 0.9031, Loss: 0.1451
# Epoch   9 Batch  182/269 - Train Accuracy: 0.9033, Validation Accuracy: 0.9054, Loss: 0.1390
# Epoch   9 Batch  183/269 - Train Accuracy: 0.9138, Validation Accuracy: 0.9047, Loss: 0.1131
# Epoch   9 Batch  184/269 - Train Accuracy: 0.9041, Validation Accuracy: 0.9055, Loss: 0.1384
# Epoch   9 Batch  185/269 - Train Accuracy: 0.9117, Validation Accuracy: 0.9053, Loss: 0.1449
# Epoch   9 Batch  186/269 - Train Accuracy: 0.9084, Validation Accuracy: 0.9052, Loss: 0.1337
# Epoch   9 Batch  187/269 - Train Accuracy: 0.8934, Validation Accuracy: 0.9055, Loss: 0.1398
# Epoch   9 Batch  188/269 - Train Accuracy: 0.9049, Validation Accuracy: 0.9044, Loss: 0.1262
# Epoch   9 Batch  189/269 - Train Accuracy: 0.8948, Validation Accuracy: 0.8999, Loss: 0.1402
# Epoch   9 Batch  190/269 - Train Accuracy: 0.8960, Validation Accuracy: 0.9054, Loss: 0.1345
# Epoch   9 Batch  191/269 - Train Accuracy: 0.8801, Validation Accuracy: 0.9053, Loss: 0.1303
# Epoch   9 Batch  192/269 - Train Accuracy: 0.8931, Validation Accuracy: 0.9066, Loss: 0.1363
# Epoch   9 Batch  193/269 - Train Accuracy: 0.9110, Validation Accuracy: 0.9043, Loss: 0.1316
# Epoch   9 Batch  194/269 - Train Accuracy: 0.8896, Validation Accuracy: 0.9075, Loss: 0.1379
# Epoch   9 Batch  195/269 - Train Accuracy: 0.8966, Validation Accuracy: 0.9075, Loss: 0.1307
# Epoch   9 Batch  196/269 - Train Accuracy: 0.8876, Validation Accuracy: 0.9057, Loss: 0.1360
# Epoch   9 Batch  197/269 - Train Accuracy: 0.8971, Validation Accuracy: 0.9052, Loss: 0.1441
# Epoch   9 Batch  198/269 - Train Accuracy: 0.8859, Validation Accuracy: 0.9009, Loss: 0.1428
# Epoch   9 Batch  199/269 - Train Accuracy: 0.8925, Validation Accuracy: 0.9008, Loss: 0.1486
# Epoch   9 Batch  200/269 - Train Accuracy: 0.8932, Validation Accuracy: 0.9021, Loss: 0.1369
# Epoch   9 Batch  201/269 - Train Accuracy: 0.8862, Validation Accuracy: 0.9035, Loss: 0.1398
# Epoch   9 Batch  202/269 - Train Accuracy: 0.8888, Validation Accuracy: 0.9100, Loss: 0.1367
# Epoch   9 Batch  203/269 - Train Accuracy: 0.8972, Validation Accuracy: 0.9014, Loss: 0.1459
# Epoch   9 Batch  204/269 - Train Accuracy: 0.8899, Validation Accuracy: 0.9033, Loss: 0.1464
# Epoch   9 Batch  205/269 - Train Accuracy: 0.9031, Validation Accuracy: 0.9059, Loss: 0.1310
# Epoch   9 Batch  206/269 - Train Accuracy: 0.8835, Validation Accuracy: 0.8940, Loss: 0.1477
# Epoch   9 Batch  207/269 - Train Accuracy: 0.9004, Validation Accuracy: 0.8948, Loss: 0.1356
# Epoch   9 Batch  208/269 - Train Accuracy: 0.9057, Validation Accuracy: 0.8982, Loss: 0.1462
# Epoch   9 Batch  209/269 - Train Accuracy: 0.9005, Validation Accuracy: 0.8997, Loss: 0.1324
# Epoch   9 Batch  210/269 - Train Accuracy: 0.8871, Validation Accuracy: 0.9014, Loss: 0.1310
# Epoch   9 Batch  211/269 - Train Accuracy: 0.9019, Validation Accuracy: 0.8994, Loss: 0.1406
# Epoch   9 Batch  212/269 - Train Accuracy: 0.9023, Validation Accuracy: 0.9005, Loss: 0.1490
# Epoch   9 Batch  213/269 - Train Accuracy: 0.8917, Validation Accuracy: 0.8984, Loss: 0.1396
# Epoch   9 Batch  214/269 - Train Accuracy: 0.8836, Validation Accuracy: 0.8962, Loss: 0.1435
# Epoch   9 Batch  215/269 - Train Accuracy: 0.9112, Validation Accuracy: 0.9015, Loss: 0.1305
# Epoch   9 Batch  216/269 - Train Accuracy: 0.8747, Validation Accuracy: 0.8966, Loss: 0.1610
# Epoch   9 Batch  217/269 - Train Accuracy: 0.8739, Validation Accuracy: 0.8872, Loss: 0.1548
# Epoch   9 Batch  218/269 - Train Accuracy: 0.9022, Validation Accuracy: 0.9008, Loss: 0.1408
# Epoch   9 Batch  219/269 - Train Accuracy: 0.9003, Validation Accuracy: 0.8986, Loss: 0.1442
# Epoch   9 Batch  220/269 - Train Accuracy: 0.9122, Validation Accuracy: 0.9018, Loss: 0.1334
# Epoch   9 Batch  221/269 - Train Accuracy: 0.8958, Validation Accuracy: 0.9030, Loss: 0.1349
# Epoch   9 Batch  222/269 - Train Accuracy: 0.9232, Validation Accuracy: 0.9039, Loss: 0.1294
# Epoch   9 Batch  223/269 - Train Accuracy: 0.8917, Validation Accuracy: 0.8999, Loss: 0.1282
# Epoch   9 Batch  224/269 - Train Accuracy: 0.8941, Validation Accuracy: 0.9023, Loss: 0.1467
# Epoch   9 Batch  225/269 - Train Accuracy: 0.8938, Validation Accuracy: 0.9008, Loss: 0.1350
# Epoch   9 Batch  226/269 - Train Accuracy: 0.9011, Validation Accuracy: 0.8986, Loss: 0.1385
# Epoch   9 Batch  227/269 - Train Accuracy: 0.9154, Validation Accuracy: 0.9035, Loss: 0.1325
# Epoch   9 Batch  228/269 - Train Accuracy: 0.8856, Validation Accuracy: 0.9041, Loss: 0.1338
# Epoch   9 Batch  229/269 - Train Accuracy: 0.8911, Validation Accuracy: 0.9001, Loss: 0.1413
# Epoch   9 Batch  230/269 - Train Accuracy: 0.8991, Validation Accuracy: 0.8968, Loss: 0.1369
# Epoch   9 Batch  231/269 - Train Accuracy: 0.9004, Validation Accuracy: 0.9021, Loss: 0.1396
# Epoch   9 Batch  232/269 - Train Accuracy: 0.8861, Validation Accuracy: 0.9048, Loss: 0.1363
# Epoch   9 Batch  233/269 - Train Accuracy: 0.9166, Validation Accuracy: 0.9060, Loss: 0.1366
# Epoch   9 Batch  234/269 - Train Accuracy: 0.9069, Validation Accuracy: 0.9006, Loss: 0.1290
# Epoch   9 Batch  235/269 - Train Accuracy: 0.9154, Validation Accuracy: 0.9060, Loss: 0.1208
# Epoch   9 Batch  236/269 - Train Accuracy: 0.8850, Validation Accuracy: 0.9070, Loss: 0.1304
# Epoch   9 Batch  237/269 - Train Accuracy: 0.9088, Validation Accuracy: 0.9054, Loss: 0.1311
# Epoch   9 Batch  238/269 - Train Accuracy: 0.9032, Validation Accuracy: 0.9056, Loss: 0.1354
# Epoch   9 Batch  239/269 - Train Accuracy: 0.9086, Validation Accuracy: 0.9134, Loss: 0.1308
# Epoch   9 Batch  240/269 - Train Accuracy: 0.9210, Validation Accuracy: 0.9081, Loss: 0.1220
# Epoch   9 Batch  241/269 - Train Accuracy: 0.9079, Validation Accuracy: 0.9055, Loss: 0.1462
# Epoch   9 Batch  242/269 - Train Accuracy: 0.9221, Validation Accuracy: 0.9075, Loss: 0.1291
# Epoch   9 Batch  243/269 - Train Accuracy: 0.9141, Validation Accuracy: 0.9130, Loss: 0.1192
# Epoch   9 Batch  244/269 - Train Accuracy: 0.8978, Validation Accuracy: 0.9123, Loss: 0.1298
# Epoch   9 Batch  245/269 - Train Accuracy: 0.8783, Validation Accuracy: 0.9131, Loss: 0.1344
# Epoch   9 Batch  246/269 - Train Accuracy: 0.8974, Validation Accuracy: 0.9102, Loss: 0.1409
# Epoch   9 Batch  247/269 - Train Accuracy: 0.9054, Validation Accuracy: 0.9082, Loss: 0.1316
# Epoch   9 Batch  248/269 - Train Accuracy: 0.8946, Validation Accuracy: 0.9039, Loss: 0.1278
# Epoch   9 Batch  249/269 - Train Accuracy: 0.9028, Validation Accuracy: 0.9041, Loss: 0.1217
# Epoch   9 Batch  250/269 - Train Accuracy: 0.9021, Validation Accuracy: 0.9132, Loss: 0.1296
# Epoch   9 Batch  251/269 - Train Accuracy: 0.9310, Validation Accuracy: 0.9121, Loss: 0.1237
# Epoch   9 Batch  252/269 - Train Accuracy: 0.8925, Validation Accuracy: 0.9090, Loss: 0.1279
# Epoch   9 Batch  253/269 - Train Accuracy: 0.8823, Validation Accuracy: 0.9118, Loss: 0.1341
# Epoch   9 Batch  254/269 - Train Accuracy: 0.9012, Validation Accuracy: 0.9158, Loss: 0.1262
# Epoch   9 Batch  255/269 - Train Accuracy: 0.9045, Validation Accuracy: 0.9163, Loss: 0.1261
# Epoch   9 Batch  256/269 - Train Accuracy: 0.8811, Validation Accuracy: 0.9141, Loss: 0.1305
# Epoch   9 Batch  257/269 - Train Accuracy: 0.8805, Validation Accuracy: 0.9123, Loss: 0.1340
# Epoch   9 Batch  258/269 - Train Accuracy: 0.9085, Validation Accuracy: 0.9087, Loss: 0.1358
# Epoch   9 Batch  259/269 - Train Accuracy: 0.9074, Validation Accuracy: 0.9100, Loss: 0.1268
# Epoch   9 Batch  260/269 - Train Accuracy: 0.8954, Validation Accuracy: 0.9063, Loss: 0.1328
# Epoch   9 Batch  261/269 - Train Accuracy: 0.8845, Validation Accuracy: 0.9070, Loss: 0.1279
# Epoch   9 Batch  262/269 - Train Accuracy: 0.9023, Validation Accuracy: 0.9048, Loss: 0.1324
# Epoch   9 Batch  263/269 - Train Accuracy: 0.8881, Validation Accuracy: 0.9097, Loss: 0.1342
# Epoch   9 Batch  264/269 - Train Accuracy: 0.8733, Validation Accuracy: 0.9141, Loss: 0.1428
# Epoch   9 Batch  265/269 - Train Accuracy: 0.9029, Validation Accuracy: 0.9100, Loss: 0.1302
# Epoch   9 Batch  266/269 - Train Accuracy: 0.8965, Validation Accuracy: 0.9120, Loss: 0.1207
# Epoch   9 Batch  267/269 - Train Accuracy: 0.9077, Validation Accuracy: 0.9156, Loss: 0.1344
# Model Trained and Saved

# %% [markdown]
# ### Save Parameters
# Save the `batch_size` and `save_path` parameters for inference.

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
# Save parameters for checkpoint
helper.save_params(save_path)

# %% [markdown]
# # Checkpoint

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
import tensorflow as tf
import numpy as np
import helper
import problem_unittests as tests

_, (source_vocab_to_int, target_vocab_to_int), (source_int_to_vocab, target_int_to_vocab) = helper.load_preprocess()
load_path = helper.load_params()

# %% [markdown]
# ## Sentence to Sequence
# To feed a sentence into the model for translation, you first need to preprocess it.  Implement the function `sentence_to_seq()` to preprocess new sentences.
#
# - Convert the sentence to lowercase
# - Convert words into ids using `vocab_to_int`
#  - Convert words not in the vocabulary, to the `<UNK>` word id.

# %%
def sentence_to_seq(sentence, vocab_to_int):
    """
    Convert a sentence to a sequence of ids
    :param sentence: String
    :param vocab_to_int: Dictionary to go from the words to an id
    :return: List of word ids
    """
    # TODO: Implement Function
    low_sentence = sentence.lower()
    word_list = low_sentence.split()
    id_list = []
    for w in word_list:
        if w in vocab_to_int:
            id_list.append(vocab_to_int[w])
        else:
            id_list.append(vocab_to_int['<UNK>'])
    return id_list


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_sentence_to_seq(sentence_to_seq)
# Out:
# Tests Passed

# %% [markdown]
# ## Translate
# This will translate `translate_sentence` from English to French.

# %%
translate_sentence = 'he saw a old yellow truck .'


"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
translate_sentence = sentence_to_seq(translate_sentence, source_vocab_to_int)

loaded_graph = tf.Graph()
with tf.Session(graph=loaded_graph) as sess:
    # Load saved model
    loader = tf.train.import_meta_graph(load_path + '.meta')
    loader.restore(sess, load_path)

    input_data = loaded_graph.get_tensor_by_name('input:0')
    logits = loaded_graph.get_tensor_by_name('predictions:0')
    target_sequence_length = loaded_graph.get_tensor_by_name('target_sequence_length:0')
    source_sequence_length = loaded_graph.get_tensor_by_name('source_sequence_length:0')
    keep_prob = loaded_graph.get_tensor_by_name('keep_prob:0')

    translate_logits = sess.run(logits, {input_data: [translate_sentence]*batch_size,
                                         target_sequence_length: [len(translate_sentence)*2]*batch_size,
                                         source_sequence_length: [len(translate_sentence)]*batch_size,
                                         keep_prob: 1.0})[0]

print('Input')
print('  Word Ids:      {}'.format([i for i in translate_sentence]))
print('  English Words: {}'.format([source_int_to_vocab[i] for i in translate_sentence]))

print('\nPrediction')
print('  Word Ids:      {}'.format([i for i in translate_logits]))
print('  French Words: {}'.format(" ".join([target_int_to_vocab[i] for i in translate_logits])))
# Out:
# INFO:tensorflow:Restoring parameters from checkpoints/dev
# Input
#   Word Ids:      [31, 138, 50, 56, 5, 165, 7]
#   English Words: ['he', 'saw', 'a', 'old', 'yellow', 'truck', '.']
#
# Prediction
#   Word Ids:      [352, 16, 311, 87, 27, 258, 4, 1]
#   French Words: il a vu un camion blanc . <EOS>

# %% [markdown]
# ## Imperfect Translation
# You might notice that some sentences translate better than others.  Since the dataset you're using only has a vocabulary of 227 English words of the thousands that you use, you're only going to see good results using these words.  For this project, you don't need a perfect translation. However, if you want to create a better translation model, you'll need better data.
#
# You can train on the [WMT10 French-English corpus](http://www.statmt.org/wmt10/training-giga-fren.tar).  This dataset has more vocabulary and richer in topics discussed.  However, this will take you days to train, so make sure you've a GPU and the neural network is performing well on dataset we provided.  Just make sure you play with the WMT10 corpus after you've submitted this project.
# ## Submitting This Project
# When submitting this project, make sure to run all the cells before saving the notebook. Save the notebook file as "dlnd_language_translation.ipynb" and save it as a HTML file under "File" -> "Download as". Include the "helper.py" and "problem_unittests.py" files in your submission.
